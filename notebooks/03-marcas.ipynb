# %%
import pandas as pd

# %%
data = pd.read_csv('../data/raw/car_raw.csv', index_col=False)

# %%
data['version'] = data['product'].str.split(' ').str[2:5].str.join(' ')

# %%
{make: list(data[data['vehicle_make']==make]['vehicle_line'].unique()) for make in data['vehicle_make'].unique()}
# Out:
# {'Audi': ['A3',
#   'Q5',
#   'A4',
#   'Q3',
#   'Q7',
#   'A5',
#   'A6',
#   'Q8',
#   'Q2',
#   'Tt',
#   'E-tron',
#   'A1',
#   'S3',
#   'S4'],
#  'Renault': ['Sandero',
#   'Twizy',
#   'Kangoo',
#   'Duster',
#   'Captur',
#   'Kwid',
#   'Logan',
#   'Symbol',
#   'Stepway',
#   'Fluence',
#   'Twingo',
#   'Megane',
#   'Koleos',
#   'Scenic',
#   'Trafic',
#   'Clio',
#   'Oroch',
#   'New',
#   'R4',
#   'Alaskan',
#   'Scala',
#   'Zoe',
#   'Safrane',
#   'Master',
#   'Sendero',
#   'Mégane',
#   'Scénic',
#   'Grand'],
#  'Honda': ['Cr-v',
#   'Pilot',
#   'Hr-v',
#   'Accord',
#   'Fit',
#   'Odyssey',
#   'Wr-v',
#   'Civic',
#   'Crx'],
#  'Ford': ['Ecosport',
#   'Explorer',
#   'Ranger',
#   'Fiesta',
#   'Escape',
#   'F-150',
#   'Bronco',
#   'Fusion',
#   'Edge',
#   'Sport',
#   'Focus',
#   'Mustang',
#   'Festiva',
#   'Raptor',
#   'F-350',
#   'Expedition',
#   'F150',
#   'Nueva'],
#  'Mini': ['Cooper',
#   'John',
#   'Countryman',
#   'Morris',
#   'Jcw',
#   'Countryman\xa0hibrid'],
#  'Volkswagen': ['Jetta',
#   'Tiguan',
#   'Voyage',
#   'Golf',
#   'Cross',
#   'Parati',
#   'Beetle',
#   'Escarabajo',
#   'Amarok',
#   'Saveiro',
#   'Polo',
#   'Gol',
#   'T-cross',
#   'Bora',
#   'Taos',
#   'Fox',
#   'Virtus',
#   'Passat',
#   'New',
#   'Crossfox',
#   'Transporter',
#   'Nivus',
#   '1300/113',
#   'Caddy',
#   'Nuevo',
#   'Spacefox'],
#  'Mazda': ['Cx-5',
#   'Cx-30',
#   '2',
#   '3',
#   'Bt-50',
#   'Allegro',
#   'B2200',
#   'Mpv',
#   'Cx-50',
#   'Cx-3',
#   'Cx-9',
#   'B2600',
#   '6',
#   '626',
#   'Mx-30',
#   'Cx-7',
#   '5',
#   'Mx-5',
#   '323',
#   'Demio',
#   'Cx-90',
#   'B2000'],
#  'Bmw': ['X3',
#   'X1',
#   'Serie',
#   'X5',
#   'M340i',
#   'I3',
#   '335',
#   'X4',
#   '120i',
#   'Cabrio',
#   '420i',
#   '128ti',
#   '225xe',
#   'M240i',
#   '340i',
#   'Ix3',
#   '2181i',
#   'X2',
#   '325i',
#   'Bmw',
#   '116',
#   'M3',
#   'Z4',
#   'M',
#   '635',
#   'M2',
#   'X6',
#   '320i',
#   'M5',
#   '218i',
#   '330i',
#   '320'],
#  'Chevrolet': ['Aveo',
#   'Bolt',
#   'Spark',
#   'Optra',
#   'Vitara',
#   'Tracker',
#   'Captiva',
#   'Luv',
#   'Onix',
#   'Sail',
#   'Silverado',
#   'D-max',
#   'N300',
#   'Super',
#   'Sonic',
#   'Samurai',
#   'Equinox',
#   'Rodeo',
#   'Chevrolet',
#   'Cruze',
#   'Grand',
#   'Traverse',
#   'Joy',
#   'Epica',
#   'Beat',
#   'Vivant',
#   'Colorado',
#   'Van',
#   'Blazer',
#   'Nhr',
#   'Swift',
#   'Trooper',
#   'Tahoe',
#   'Zafira',
#   'Hhr',
#   'Trailblazer',
#   'Wagon',
#   'Camaro',
#   'Cheyenne',
#   'Corsa',
#   'Orlando',
#   'N400',
#   'Chevy',
#   'Cobalt',
#   'Sprint',
#   'Esteem'],
#  'Hyundai': ['Accent',
#   'Tucson',
#   'Santa',
#   'Creta',
#   'Elantra',
#   'Starex',
#   'Graviti',
#   'New',
#   'Getz',
#   'H100',
#   'Grand',
#   'Veracruz',
#   'I35',
#   'Atos',
#   'Hb20x',
#   'Santamo',
#   'Kona',
#   'I20',
#   'Hb20s',
#   'Sonata',
#   'Ioniq',
#   'I30',
#   'I10',
#   'Porter',
#   'Eon',
#   'Veloster',
#   'Hb20',
#   'H1'],
#  'Hafei': ['Minyi', 'Xinyi'],
#  'Ram': ['V700', '700', 'Ram', '1000', '1500'],
#  'Citroën': ['C4',
#   'C3',
#   'C-elysée',
#   'Berlingo',
#   'C5',
#   'Grand',
#   'Xsara',
#   'Ds3'],
#  'Toyota': ['4runner',
#   'Fj',
#   'Prado',
#   'Hilux',
#   'Corolla',
#   'Yaris',
#   'Fortuner',
#   'Land',
#   'Rav4',
#   'Tundra',
#   'Tacoma',
#   'Estacas',
#   'Burbuja',
#   'Highlander',
#   'Rush',
#   'Sequoia'],
#  'Nissan': ['Frontier',
#   'Qashqai',
#   'Murano',
#   'Sentra',
#   'March',
#   'X-trail',
#   'Np300',
#   'Note',
#   'D22',
#   'Kicks',
#   'Xtrail',
#   'Versa',
#   'Altima',
#   'Tiida',
#   'Pathfinder',
#   'Patrol',
#   'Navara',
#   'D21',
#   'D22/np300',
#   'Leaf',
#   'Almera',
#   'Urvan',
#   'X',
#   'Juke',
#   'Primera',
#   'Ad'],
#  'Mercedes-benz': ['Ml',
#   'Clase',
#   'Cla',
#   'Vito',
#   'Glc',
#   'E',
#   'C',
#   'Mb',
#   'Amg',
#   '350',
#   '250',
#   'B',
#   '190',
#   'Gle',
#   'Glc250',
#   'C200',
#   'Serie',
#   'Gla',
#   '4.6',
#   '2004',
#   '230',
#   '180',
#   'A',
#   'Gl',
#   'C250',
#   'Glk300',
#   'Clk'],
#  'Ssangyoung': ['Kyron'],
#  'Jeep': ['Compass',
#   'Willys',
#   'Renegade',
#   'Grand',
#   'Wrangler',
#   'Cherokee',
#   'Gladiator'],
#  'Suzuki': ['Swift',
#   'S-cross',
#   'Grand',
#   'Vitara',
#   'Celerio',
#   'Alto',
#   'Jimny',
#   'Baleno',
#   'Ertiga',
#   'Xl7',
#   'Sj',
#   'S-presso',
#   'Xl-7',
#   'Ciaz',
#   'Apv'],
#  'Subaru': ['Xv',
#   'Forester',
#   'Legacy',
#   'Outback',
#   'Impreza',
#   'Evoltis',
#   'Tribeca',
#   'Wrx',
#   'Cross'],
#  'Kia': ['Sportage',
#   'Cerato',
#   'Rio',
#   'New',
#   'Soul',
#   'Picanto',
#   'Sorento',
#   'Niro',
#   'Carens',
#   'Stonic',
#   'Carnival',
#   'Seltos',
#   'K3',
#   'K',
#   'Optima',
#   'Grand',
#   'Sonet',
#   'Tonic',
#   'Cadenza',
#   'Sedona',
#   'Soluto',
#   'Mohave',
#   'Opirus'],
#  'Mitsubishi': ['2.6',
#   'Lancer',
#   'Montero',
#   'Nativa',
#   'Outlander',
#   'L200',
#   'Asx',
#   'L300',
#   'Gala',
#   'Eclipse'],
#  'Land': ['Rover'],
#  'Volvo': ['Xc90', 'Xc60', 'S40', 'S60', 'V40', 'Xc40', 'C30', 'C40'],
#  'Chery': ['Qq', 'Yoya', 'Tiggo', 'Yoki', 'Yoyo', 'Qq3'],
#  'Byd': ['Song', 'Idolphin', 'Yuan', 'Qin', 'Quin', 'Dolphin'],
#  'Dahiatsu': ['Delta'],
#  'Dodge': ['Journey', 'Ram', 'Coronet', 'Durango'],
#  'Jac': ['E10x', 'S2', 'J3', 'S3', 'B-cross'],
#  'Ds': ['Ds3', 'Ds4', 'Ds7'],
#  'Fiat': ['Strada',
#   'Uno',
#   'Fiorino',
#   '500',
#   'Mobi',
#   'Pulse',
#   'Cronos',
#   'Palio',
#   '500c'],
#  'Peugeot': ['3008',
#   '207',
#   '206',
#   '407',
#   '2008',
#   '308',
#   'Partner',
#   '5008',
#   '306',
#   '208',
#   'Expert',
#   '307',
#   '301',
#   '406'],
#  'Mg': ['Zs', '3', 'Gt', 'Marvel', '350'],
#  'Daihatsu': ['Grand', 'Terios', 'Sirion'],
#  'Dfm/dfsk': ['Eq6410lf', 'Eq6390pf22qx', 'Van', 'Glory', 'Eq1020tf'],
#  'Changan': ['Cs', 'Cargo', 'Mini', 'Cs15'],
#  'Seat': ['Arona', 'Altea', 'Leon', 'Ibiza', 'Ateca'],
#  'Porsche': ['Macan', '911', 'Boxster', 'Cayenne'],
#  'Ssangyong': ['Actyon',
#   'Korando',
#   'Rexton',
#   'Kyron',
#   'Torres',
#   'Tivoli',
#   'Rodius'],
#  'Great': ['Wall'],
#  'Baic': ['Kenbo'],
#  'Cupra': ['Formentor'],
#  'Opel': ['Crossland', 'Grandland'],
#  'Alfa': ['Romeo'],
#  'Jetour': ['X70'],
#  'Lexus': ['Gx', 'Lx', 'Rx'],
#  'Skoda': ['Yeti', 'Rapid', 'Fabia', 'Felicia', 'Octavia', 'Superb'],
#  'Jmc': ['Landwind'],
#  'Zhidou': ['D2s'],
#  'Daewoo': ['Cielo', 'Nubira', 'Damas', 'Racer'],
#  'Jaguar': ['F-pace', 'E-pace'],
#  'Hummer': ['H3'],
#  'Dfsk': ['Van', 'K05', 'Glory'],
#  'Brilliance': ['V5'],
#  'Foton': ['Cargo', 'Tunland', 'Mini'],
#  'Mahindra': ['Kuv100', 'Pik-up'],
#  'Huanghai': ['Tucson'],
#  'Chrysler': ['Neon'],
#  'Karry': ['Yo-yo'],
#  'Lada': ['2105'],
#  'Isuzu': ['Amigo'],
#  'Vitara': ['Glx']}

# %%
{depto: list(data[data['location_state']==depto]['location_city'].unique()) for depto in data['location_state'].unique()}
# Out:
# {'Bogotá D.C.': ['Usaquén',
#   'Puente Aranda',
#   'Suba',
#   'Fontibón',
#   'Chapinero',
#   'Barrios Unidos',
#   'Engativa',
#   'Teusaquillo',
#   'Kennedy',
#   'Martires',
#   'Rafael Uribe Uribe',
#   'Antonio Nariño',
#   'Tunjuelito',
#   'Bosa',
#   'Ciudad Bolívar',
#   'Usme',
#   'San Cristobal Sur',
#   'Santa Fe',
#   'La Candelaria'],
#  'Cundinamarca': ['Chía',
#   'Cota',
#   'La Calera',
#   'Facatativá',
#   'Soacha',
#   'Mosquera',
#   'Cajicá',
#   'Tabio',
#   'Cáqueza',
#   'Funza',
#   'Fusagasugá',
#   'Tenjo',
#   'Madrid',
#   'Zipaquirá',
#   'Villeta',
#   'La Vega',
#   'Tocancipá',
#   'Sopó',
#   'Bogota',
#   'Susa',
#   'Sasaima',
#   'Sibaté'],
#  'Antioquia': ['Envigado',
#   'La Estrella',
#   'Medellín',
#   'Sabaneta',
#   'Bello',
#   'Girardota',
#   'Retiro',
#   'Itaguí',
#   'El Carmen de Viboral',
#   'Copacabana',
#   'Caldas',
#   'Abejorral',
#   'Caucasia',
#   'La Ceja',
#   'Rionegro',
#   'Gómez Plata'],
#  'Santander': ['Floridablanca', 'Bucaramanga', 'Barichara', 'Barbosa'],
#  'Boyaca': ['Tunja', 'Duitama', 'Chiquinquirá'],
#  'Valle Del Cauca': ['Cali', 'Roldanillo'],
#  'Meta': ['Villavicencio'],
#  'Tolima': ['Melgar'],
#  'Quindio': ['Armenia'],
#  'Huila': ['Pitalito'],
#  'Norte De Santander': ['Cúcuta']}

# %%
{depto: list(data[data['location_state']==depto]['location_city'].unique()) for depto in data['location_state'].unique()}
# Out:
# array([1954, 1966, 1971, 1977, 1980, 1981, 1982, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021,
#        2022, 2023, 2024])

# %%
{line: list(data[data['vehicle_line']==line]['version'].unique()) for line in data['vehicle_line'].unique()}
# Out:
# {'A3': ['1.8t',
#   '1.8 Tfsi Advance',
#   '1.8 Sportback Ambition',
#   '1.8 Sportback',
#   '1.2 Attraction 3',
#   '1.8t Hb Mecánico',
#   '2.0 8p Sportback',
#   '1.8 L',
#   '1.2 Fsi Turbo',
#   '1.4 Tsfi Advance',
#   '2.0 Progressive',
#   '1.2 Tfsi Ambition',
#   '1.8 Tfsi Ambition',
#   '2.0 Fsi Coupe',
#   '1.6',
#   '2.0 8v Sportback',
#   '2.0 Sportline Sedan',
#   '19 Sportline',
#   '1.2  8v',
#   '1.6 Coupe'],
#  'Sandero': ['1.6 Life+',
#   '1.6 Expression 90',
#   '1.6 Life',
#   '1.6 Gt Line',
#   '1.6 Expression',
#   '1.6 Life Ph2',
#   '1.6 Authentique',
#   '1.6 Dynamique',
#   '2.0 Rs Mt',
#   '1.6 Life Mt',
#   '1.6 Gt',
#   '1.6 Authentique /',
#   '1.6',
#   '1.6 Automatique',
#   'Expression',
#   'Automatico 1.6 Dynamique',
#   '1.6 Authentic',
#   'Zen Mt 1.6',
#   '1.6 Stepway',
#   'Gt Line',
#   'Autenthique/life',
#   'Dynamique At',
#   '1.6 Intens /',
#   'Rs',
#   '1.6 Zen Mt',
#   '1.6 Automatiq',
#   '1.6 Dynamique At',
#   '1.6 Expression Mt',
#   '1.6 Authentique 90',
#   'Life Mt Life',
#   '1.6 Life +',
#   '1.6 Dynamique 110',
#   '1.6 Zen',
#   '1.6 Authentique 85',
#   '1.6 Dynamique 90',
#   '1.6 Tripadvisor Mt',
#   '1.6 Authentique Tweed',
#   '1.6 Authentique Mt',
#   'Authentique /life 1.2',
#   '1.6 Intens',
#   '1.6 Life+ Access',
#   'Authentique/life',
#   '1.6 Polar Mt',
#   'Life + 16',
#   '1.6 Dynamique Mecanico',
#   'Authentique',
#   '1.6 Exclusive Mt',
#   'Intens/at',
#   '1.6 Polar',
#   '1.6  Authentique',
#   '1.6 Exclusive'],
#  'Cr-v': ['2.0 Rvi',
#   '2.4 Lx',
#   '2.4 City Plus',
#   '2.4 5dr Lxc',
#   '2.0 At',
#   '2.0 Ex',
#   '2.4 Ex',
#   'Lx',
#   '2.4 Lx At',
#   '2.4 Ex L',
#   '2.4 L 5dr',
#   '2.4',
#   'Rvi At',
#   '2.4 Exl',
#   '2.4 5dr 2wd',
#   'Ex L',
#   '1.5',
#   '1.5 Exl',
#   'Ex',
#   '5dr Exl 4wd',
#   '1.5 Vtec Awd',
#   '2.4 Lx 4x4',
#   '2.4 5dr',
#   'Ex L C',
#   '2.0 Rvsi',
#   '2.4 L X',
#   '2.4 2wd Lx',
#   '2.4 Ex At',
#   '2.4 Exl 4x4',
#   '2.4 Lxc 2wd',
#   '2.0 4wd'],
#  'Ecosport': ['2.0 4x4',
#   '2.0 Titanium At',
#   '2 2.0 Titanium',
#   'S',
#   '2.0 Freestyle',
#   '2.0 L 4x2',
#   '1.5 Se',
#   'Se',
#   'Freestyle',
#   '2.0 Titanium 4x2',
#   '2 1.5 Se',
#   '2.0 Se',
#   '2.0 Freestyle 4x4',
#   '2.0 Titanium',
#   '2.0 Freestyle 4x2',
#   '2.0 Titanium Tp',
#   'Titanium',
#   '1.5 Se Mt',
#   '2.0 L 4x4',
#   'Titanium 4x2 2.0',
#   '2.0 4x2',
#   '2.0l Mt 4x4',
#   '2.0 Titanium Edición',
#   '1.5 Se At',
#   '2.0 Titanium Mt',
#   '2.0 Intense',
#   '2.0 16v At',
#   '2.0 Fresstyle',
#   '2.0 Se 4x2',
#   'Titanium At 2.0',
#   '2.0 Se At',
#   '2.0 4x2 At',
#   'Xlt',
#   '2.0 Lt Mt',
#   '2.0 Se Freestyle',
#   '2.0 L',
#   '2.0l At 4x2',
#   '2.0 Mt 4x4',
#   'Se Mt 2000cc'],
#  'Cooper': ['Cooper Se',
#   '1.6 R57 S',
#   '1.5 F55 Salt',
#   'S 2.0 Chili',
#   '1.5 Coupe Salt',
#   'R56 1.6 Coupe',
#   '1.5 F56 Coupe',
#   '2.0 F56 S',
#   'S 1.6 Country',
#   'F56 Se Iconic',
#   '2.0 S Pat',
#   'S Clubman 1.6',
#   'S S Coupe',
#   'Se Iconic',
#   'S 1.6',
#   'S 2.0 Chilli',
#   'S 2.0 ',
#   'S 1.6 Chili',
#   'F56 Lci Se',
#   '1.6 R57 Cabriolet',
#   '1.6 R56 Coupe',
#   'S Countryman 2.0',
#   'Se Electico',
#   'S 2.0 Mt',
#   'S 2.0 Iconic',
#   'R56 S',
#   'John Cooper Works',
#   '2.0 F55 S',
#   '1.6 R59 S',
#   'Eléctrico F56 Lci',
#   '1.6 Rs Edicion',
#   '1.5 F55 Classic'],
#  'Jetta': ['2.0 Europa',
#   '2.0 Comfortline At',
#   '2.0 Trendline',
#   '2.0 Europa Clasico',
#   '2.0 Europa At',
#   '1.4 Conforline',
#   '2.0 Gli',
#   '1.4 Tsi Comfortline',
#   'New',
#   '2.5 2.5 Turbo',
#   '1.4 Highline',
#   '2.0 Classic',
#   '1.8 Gli',
#   '1.8 Comfortline',
#   '2.5 Comfortline At',
#   '1.6 Tsi',
#   '2.0 Trendline Mt',
#   '2.0 2007',
#   '1.4',
#   '2.5 Highline',
#   '1.4 Tsi Highline',
#   '1.4t Comfortline Tsi',
#   'Nuevo Jetta 2.0',
#   '2.0 Trendline At',
#   '2.0 Comfortline',
#   '2.0 Trendline 4',
#   'Comfortline',
#   'Trendline 2.5',
#   '1.4 Sportline',
#   '2.5 Trendline',
#   'New Jetta 2.5',
#   'Nuevo Jetta Comfortline',
#   '2.0 Europa Mt',
#   'V 1.8 Gli',
#   'Highline',
#   '2.5 Trendline At',
#   '2.0 Trendline Clasico',
#   '2.5',
#   '2.0 Clasico At',
#   '1.8',
#   'Trendline At 2.0',
#   'Trendline Mt 2.0',
#   '1.4 Highline Turbo',
#   '2.5 Comfortline Tp',
#   '2.5 Comfortline',
#   'Comforline',
#   'Europa',
#   '2.o Europa',
#   '1.4 Tsi R',
#   'Comforline 1.4',
#   'Gli',
#   '1.8t Triptonico',
#   'Jetta Europa 2.0',
#   '2.0 Clasico Mecanico',
#   '2.0 Tdi',
#   '2.0t Gli',
#   '2.5 New Jetta',
#   'Trendline',
#   'Trendline 2.0',
#   '2.0 Trendlina'],
#  'Cx-5': ['2.0 Touring Camioneta',
#   '2.0 Touring',
#   '2.5 Grand Touring',
#   '2.0 Touring At',
#   '2.5 Touring',
#   '2.0 Touring Station',
#   '2.0 Prime',
#   '2.0 Touring Tp',
#   '2.0 Grand Touring',
#   'Grand Touring Lx',
#   '2.0 Mid Fwd',
#   'Touring At 2.04x2',
#   '2.5 Gran Touring',
#   '2.5 Touring 4x2',
#   '2.0 High Fwd',
#   '2. Touring At',
#   'Grand Touring',
#   'Touring',
#   '2.0 High',
#   'Touring Wagon',
#   '2.5 Touring At',
#   '1.6 Touring At',
#   '2.0',
#   'Grantouring',
#   '2.0 Prime At',
#   'Touring Tp',
#   'Grand Touring Carbon'],
#  'X3': ['2.0 Xdrive20d',
#   '2.0 Xdrive30i',
#   '2.0 F25 Xdrive',
#   '2.0 G01 Xdrive30i',
#   '3.0 F25 Xdrive35i',
#   '2.0 F25 Xdrive20i',
#   '2.0 F25 Xdrive28i',
#   '3.0 F25 Xdrive30d',
#   'E83 3.0si',
#   '2.0 G01 Xdrive20d',
#   '2.0 Xdrive20i 2015',
#   '3.0 Xdrive30i Executive',
#   '2.0 Xdrive 28i',
#   '2.0 Xdrive20i 2014',
#   'Xdrive 20 I',
#   '2.0 Xdrive 20i',
#   '2.0 Xdrive30e Tp',
#   '2.0 Xdrive30i At',
#   '3.0 Si',
#   'Xdrive 28 I',
#   '2.5 Si At',
#   'X3 Xdrive 28',
#   '3.0 Cc',
#   '3.0',
#   '2.0 Xdrive30i Tp',
#   '2.5 E83 25si',
#   '2.0 F25 Xdrive20d',
#   '[f25] Xdrive20i Tp',
#   '3.0 M40i 4x4',
#   'E83 3.0i',
#   '3.0 F25 35i',
#   '3.0 F25 Xdrive28i',
#   'Xdrive 20d'],
#  'Cx-30': ['2.0 Prime',
#   '2.0 Touring',
#   '2.0 Grand Touring',
#   'Touring At',
#   '2.0 Touring At',
#   '2.5 Grand Touring',
#   'Touring',
#   'Grand Touring',
#   'Grand Touring Lx',
#   '2.4 Grand Touring',
#   'Gran Turing Lx',
#   '2.0 Cx-30 Grand',
#   '2.0 At 4x2',
#   '2.0 Prime At',
#   '2.0 Prime Mt',
#   'Touring Tp 2.0',
#   '2.0 At',
#   'Grand Touring Hybrid'],
#  '2': ['1.5 Touring',
#   '1.5 Grand Touring',
#   '1.5 15hm8',
#   '1.5 15na1 Sedan',
#   '1.5 Mt Hatchback',
#   'Hb',
#   '1.5',
#   '2 1.5 Grand',
#   '1.5 Touring Automatico',
#   '1.5 15ha8 At',
#   'Sport 1.5 Grand',
#   '1.5 Touring Mt',
#   '1.5 15ha8',
#   '2.5 Old New',
#   'Hatchback',
#   '1.5 Touring At',
#   '15ha1c  Mt',
#   'Grand Touring Lx',
#   '1.5 Touring Sedan',
#   '1.5 Prime',
#   '1.5 Prime Sedan',
#   '1.5 Touring Aut',
#   '1.5 15hm1c',
#   '1.5 15ha1c',
#   '1.5 Sedan At',
#   '1.5 Mt',
#   '1.5 Touring Hatchback',
#   '1.5 Hb',
#   '1.5 Sedan Grand',
#   '1.5 Hatchback At',
#   '1.5 At Hb',
#   '1.5 Sky Active',
#   '1.5 Prime Hatch',
#   'Sedan 1.5 Touring',
#   'Touring',
#   'Hatch Back 1.5',
#   'Hatchback 1.5 Grand',
#   'Sedan Prime Sedan',
#   '1.5 Mt Hb',
#   '1.5 At',
#   'Glx Grand Touring',
#   '1.5 15hm1c Mt'],
#  'Aveo': ['Emotion',
#   'Emotion 1.6 Gls',
#   '1.6 Gti Limited',
#   '1.6 Sd',
#   'Emotion 1.6 Gti',
#   'Emotion 1.6l',
#   '1.4 Family',
#   '1.5 Family',
#   'Family',
#   '1.6i Emotion Mt',
#   '1.6 Emotion Gt',
#   'Emotion 1.6 Gt',
#   '1.6 Gti',
#   'Emotion 1.6 Emtion',
#   '1.6 Five',
#   '1.6 Emottion',
#   '1.5 Family Sedan',
#   'Emotion 1.6',
#   '1.6 L',
#   'Emotion 1.6l Automatico',
#   '1.6 Gti Mt',
#   '1.5 Family Mt',
#   '1.6 Mt',
#   '1.4 Ls',
#   '1.4 Five',
#   '1.6',
#   '1.4 Sd',
#   '1.6 Five Mt',
#   '1.6 Gti Coupé',
#   'Sd',
#   '1.4 Five 5p',
#   '1.6 Emotion',
#   'Ls'],
#  'Accent': ['Gls Mt 1600cc',
#   '1.4i Gl',
#   '1.6 I25',
#   '1.4l 5 P',
#   'Advance',
#   '1.6 Advance',
#   'I25 Gl',
#   '1.6l 4 P',
#   '1.4 Gls',
#   '1.6 Premium Mecánica',
#   '1.5 Gls',
#   '1.6l 5 P',
#   '1.4 Gls Mt',
#   '1.6 Premium',
#   '1.6 Gls',
#   '1.6 Hb20s',
#   '1.6 I25 Hb',
#   '1.5 Gls 4',
#   '1.4l 4 P',
#   '1.4 Gls Mecanico',
#   '1.6 Gls 4',
#   'Vision 1.6 Gls',
#   '1.3 L',
#   '1.4 Gl',
#   '1.6 I25 Gl',
#   '1.6 Gl',
#   '1.6 Hb20s Advance',
#   '1.5 L',
#   '1.6 Gl Tp',
#   '1.6 L Mt',
#   '1.4 Accent Gl',
#   '1.6 Advance Hb20',
#   '1.4 5p Gl'],
#  'Minyi': ['Hfj1020a [asl] Mt'],
#  '3': ['2.0 Touring',
#   '2.0 Grand Touring',
#   '2.0 Sport Prime',
#   '2.0 Prime',
#   '1.5 Comfort At',
#   '2.0 Sport Turing',
#   'Touring',
#   '2.0 Sport Touring',
#   '2.5 Grand Touring',
#   '1.6 All New',
#   '1.6',
#   '2.0 Touring 2022',
#   '2.0 Lxha7',
#   '1.6 Z6nm0 All',
#   '1.5 Comfort',
#   '2.0 Lxna0 All',
#   '2.0 Touring Mhev',
#   '2.0 Prime Mecanico',
#   '2.0 Sport Grand',
#   '1.6 Z6nm7',
#   'Grand Touring',
#   '2.0 Touring Hybrid',
#   '1.6 Z6nm5',
#   '1.6 Z6ha7',
#   'Sport Grand Touring',
#   'Touring 2.0',
#   '2.0 Touring Hibrido',
#   '2.0',
#   '1.6 Z6na0 All',
#   '1.6 Z6na7',
#   'Z6hm7 Mt 1600cc',
#   '2.0 Touring Mt',
#   '2.0 Lfha5',
#   '2.0 Touring Tp',
#   '2.0 Prime Mt',
#   '2.0 Touring At',
#   '2.0 Touring Lx',
#   'Touring Tp 2000cc',
#   '2.0 Lxna7',
#   'Touring Lx At',
#   '2.0 Lxhm7',
#   '2.0 All New',
#   '1.6 Z6hm7',
#   '2.0 At',
#   '1.6 At 2010',
#   'Touring Mhev',
#   'Touring At 2.0',
#   '2.0 Touriing Mt',
#   '2.0 Touring Mecanio',
#   '1.6 Z6hm0 All',
#   'Touring Mhev Hibrido',
#   '1.5 Vti'],
#  'Bolt': ['Euv'],
#  'V700': ['1.4 Rapid', '1.4 Carga', '1.4'],
#  'Spark': ['Gt 1.2 Ltz',
#   '1.2 Gt Ls',
#   'Gt 1.2 Lt',
#   '1.2 Ltz Premie',
#   'Gti 1.2 Gt',
#   'Go Mt Full',
#   '1.0 Life',
#   '1.2 Gt',
#   '1.0 Go',
#   '1.0 Cronos',
#   '1.2 Gt Active',
#   'Gt',
#   '1.2 Gt M300',
#   '1.3 Ltz',
#   '1.2 Gt Ltz',
#   'Gt 1.2 Mt',
#   '1.0 Lt M200',
#   '1.0 Ls',
#   '1.2 Gt Mt',
#   'Gt 1.2 Ls',
#   '1.0 Lite',
#   '1.0 Spark',
#   '1.0 Life Lujo',
#   '1.0 Lt',
#   'Gt 1.2 Premier',
#   'Gt 1.2 Rec',
#   '1.2 Ltz Mt',
#   '1.0 Lt Mt',
#   '1.0 Local',
#   'Gti',
#   '1.0 Mt',
#   'Gt 1.2 Gt',
#   'Gt 1.2'],
#  'C4': ['Cactus C4 ',
#   '1.6',
#   'Cactus 1.6 Feel',
#   'Cactus 1.6 Shine',
#   '1.6  Cactus',
#   'Cactus Shine',
#   'Cactus',
#   'Cactus 1.6l Feel',
#   '1.6 Sx Mt',
#   '2.0 Vts',
#   '1.2 Turbo',
#   'Picasso 2.0 Confort',
#   '1.6 Cactus'],
#  'Q5': ['2.0 Tdi S-tronic',
#   '2.0 Tfsi Quattro',
#   '3.0 Tfsi Attraction',
#   '2.0 Tfsi S-tronic',
#   '2.0 Tfsi Mhev',
#   '2.0',
#   'Quattro Luxury',
#   '2.0 Tdi Quattro',
#   '2.0 2015',
#   '2.0 45 Tfsi',
#   'Tfsi Quattro Advanced',
#   'Tfsi Sport',
#   '3.0 Tfsi Quattro',
#   'Tfsi Mhev Quattro',
#   '2.0  Quattro',
#   '2.0 Attraction',
#   '3.2 Fsi S-tronic',
#   '2.0 Tfsi-s Tronic',
#   '2.0 Sportback Prestige',
#   'Lmt022 Quattro Advanced',
#   '2.0 Advance Tfsi',
#   '3.0 Tfsi Sport',
#   '2.0 Sportback Tfsi',
#   '.0 Tfsi S-tronic',
#   '2.0 Tfsi 45',
#   '20 Tfsi S-tronic'],
#  '4runner': ['4.0 Sr5 Fl',
#   '4.0 Limited Blindaje',
#   '4.0 Limited Fl',
#   '4.0 Sr5',
#   'Sr5',
#   '4.0 Limited',
#   '4.0 Limited Automática',
#   '4.0 Sr5 Automática',
#   'Limited',
#   '4.0 Sr5 Limited',
#   '4.0 Sr5 At',
#   '4.0 Sr-5',
#   '4.0 4runner Sr5',
#   '4.0 Srv',
#   '4.0 Sr5 Gasolina'],
#  'Tiguan': ['Trendline 1.4 Tsi',
#   'Allspace Comfortline 2.0',
#   '1.4 Allspace Trendline',
#   'Allspace Highline 2.0',
#   '1.4t Trendline',
#   '2.0 Trend &',
#   '2.0 Sport &',
#   'Allspace Trendline 1.4',
#   '4x4 2.0 Tsi',
#   '2.0 T Sport',
#   'Elegance 2.0 Tsi',
#   'Trend&fun',
#   '2.0 Elegance Emotion',
#   '2.0 Tsi 4',
#   'Allspace Trendline 2.0',
#   '2.0 T',
#   '2.0 Trend Style',
#   'Tsi 4 Motion',
#   '2.0 Tsi',
#   'Elegance 20 Tsi',
#   '2.0 Tsi Elgance'],
#  'Frontier': ['2.5l Automática Diésel',
#   '2.5 D22/np300',
#   '2.5 Np300 Xe',
#   '2.4 24l 4x2',
#   '2.5 D22/np300 Estacas',
#   '2.4 Np300',
#   'Np300 Automatica 4x4',
#   '2.5 Np300 Se',
#   '2.4l 4x2',
#   'Np300 Frontier',
#   '2.5 Mt ',
#   '2.5l Mecánica Diésel',
#   '2.4l',
#   '2.4 24l',
#   '2.5 Xe 4x4',
#   '2.4 Np300 4x2',
#   '2.5 Np 300',
#   '2.4 Np300 Furgón',
#   '2.5l Asl Gasolina',
#   '2.4 4x2 D22/np300',
#   '2.4 D22/np300',
#   'D22 Np300 Estacas',
#   '2.5  D22/np300',
#   '2.5 Np300 Estacas',
#   '2.5t D22/np300 Estacas',
#   '2.5 D22/ Np300',
#   '2.4 D22/np300 Estacas',
#   '2.5l',
#   'Np 300 4x4',
#   'Frontera D22 Np300',
#   '2.5 S',
#   '2.4 4x2',
#   '2.5 Le 4x4',
#   '3.0 Dx D22',
#   '2.5 Se Mt',
#   '2.4 D22/np300 4x2',
#   'Frontier Np300 2.5',
#   '2.4 Std D22',
#   '2.5l 4x2 Estacas',
#   '2.5 Le',
#   'Np300',
#   '2.5 Np300',
#   '2.5 Diesel 4x4',
#   '2.5 Np300 Diesel',
#   '2.5 4x2',
#   '2.5 Np300 4x2',
#   'D22/np 300 Frontier',
#   'D22/np300 Estacas',
#   '2.4l 4x4',
#   'Np300 2.5 4x4',
#   '2.5 Blindaje 2',
#   '2.5 Sabanera 4x2',
#   '2.5 Pro4x At',
#   '2.4 Xe',
#   '2.3 Xe Euro',
#   '3.0 D22 4x4',
#   '3.0 D22',
#   'Le 4x4',
#   '2.5l 4x2',
#   '2.4 4x2 Np300',
#   '2.5 Xe'],
#  'Explorer': ['3.0 St',
#   '3.5 Limited',
#   '2.3 Limited 4x4',
#   '3.5 Xlt',
#   '2.3 Xlt',
#   '2.3 Xlt 4x4',
#   'Limited',
#   '2.3 Xlt Ecoobost',
#   '4.0 Xlt Elite',
#   '4.0 Ne Sport',
#   '3.0 Xlt At',
#   '4.6 Eddie Bauer',
#   '2.3 Limited',
#   '3.5 Limited Tp',
#   '3.5 Limited 4x4',
#   '2.0 Titanium 2.0',
#   '4.0 Xlt',
#   '2.3',
#   '3.5 Limited Blindada',
#   'Sport',
#   'Limited 4x4'],
#  'Ranger': ['3.2 Xls',
#   '3.2 Limited',
#   '2.2 Xl F22cl3',
#   '3.2 Limited 4x4',
#   '2.2 Xlt Mt',
#   '2.0 Raptor 4x4',
#   '2.2 Xlt',
#   'Estacas 4x4 2.2',
#   '2.6',
#   'Xlt Ci',
#   '2.5 Ranger 4x4',
#   'Raptor 2.0',
#   '2.5 Xls',
#   '2.2 Xl Estacas',
#   '2.5 4*2',
#   '3.2 Xlt',
#   '2.3 Mt',
#   '3.2 Xls Mt',
#   '2.6 Xlt',
#   'Xlt',
#   '3.2 Xl',
#   '2.2 Xl',
#   '3.2 Fx4',
#   '2.5 Xlt',
#   '3.2 Xlt At',
#   '2.0 Raptor',
#   '3.2 4x4',
#   '3.2 Xls 4x4',
#   'Limited'],
#  'Ml': ['3.5',
#   '3.5 At',
#   '2.1 250 Cdi',
#   '3.5 4matic',
#   '5.5',
#   '2.2 Cdi',
#   '350 3.5 At',
#   '350 3.5 4-matic',
#   '5.0'],
#  'Bt-50': ['2.2 4x2 Mt',
#   '2.5 B25d49',
#   '2.2 B22c29 4x2',
#   '2.6 B26d49',
#   '2.2 Mt',
#   '2.2 B22d29',
#   '3.2 Professional',
#   '2.2 B22',
#   'All New 3.2',
#   '2.6',
#   'B22d29',
#   '2.5 4x4 Diesel',
#   '2.2 B22cs7 4x2',
#   '2.2 Doble Cabina',
#   '2.2 4x2 Gasagol',
#   '2.5 4x4',
#   '2.6 Mt 4x4',
#   '2.2 B22d29 Dc',
#   '2.5',
#   'B22d29 Mt 2200cc',
#   '2.5 Estacas',
#   '2.5 Diesel 4x4'],
#  'Voyage': ['1.6 Comfortline',
#   '1.6 Conforline',
#   'Comfortline',
#   '1.6 Trendline',
#   '1.6 Trendline At',
#   '1.6 Power 101',
#   'Comfortline 1.6 Mt',
#   '1.6 Highline',
#   '1.6 Comfortline Mt',
#   '1.6 Highline Mt',
#   '1.6 Trendline Mt',
#   '1.6 Power',
#   'Trendline'],
#  'Twizy': ['Technic', 'Cargo', 'Technic Mt 13kw', 'Technic At'],
#  'Kangoo': ['1.6 Express',
#   '1.4 Express 4',
#   'Vu Van Carga',
#   '1.6 Carga',
#   '1.6 Express Mt',
#   '1.6',
#   'Express Mt 1.6',
#   '1.6 Express Confort',
#   '1.6 Express 4',
#   '1.6 Express 2',
#   'Express'],
#  'Fj': ['Cruiser 4.0 V6', 'Cruiser 4.0', '4.3'],
#  'Clase': ['Gle 3.0 450',
#   'E 2.0 Cgi',
#   'A 1.6 A',
#   'A 200 Progressive',
#   'Gle 450 3.0',
#   'Gla 1.6 Urban',
#   'Cla 200 1.6',
#   'C 180 1.8',
#   'E 2.0 Exclusive',
#   'C 1.6 Avantgarde',
#   'E 1.8 Cgi',
#   'C 2.0 Avantgarde',
#   'Glb 1.3 Amg',
#   'C 2.0 Cabriolet',
#   'Glc 2.0 4matic',
#   'C 1.8 Classic',
#   'Cla 1.6 Limited',
#   'Gla 1.6',
#   'E 200 2.0',
#   'Cla 1.6 Essential',
#   'Cla Cla 180',
#   'Cla 1.6 180',
#   'Cla 1.6 Urban',
#   'Cla 1.4 Amg',
#   'C 1.8 Cgi',
#   'Glc 2.0 300',
#   'C 1.5 Amg',
#   'Cla 1.6',
#   'C 350 3.5',
#   'A 1.3 A200',
#   'E 240 Elegance',
#   'C 2.0 Coupe',
#   'Gla 1.3t Amg',
#   'Glk 3.5 4matic',
#   'Gls 3.0 450',
#   'Cla 180 1.6',
#   'C 2.0 Cgi',
#   'Glc 2.0 250',
#   'C 1.8 180',
#   'Gls 3.0 ',
#   'A 1.4 200',
#   'E 1.8 W211',
#   'C 180 ',
#   'A 1.4 A200',
#   'Cla 180 At',
#   'Gle 2.0 4matic',
#   'Gle 3.0 Coupe',
#   'C 180 1.6',
#   'Cla 1.6 2015',
#   'C 1.8 Elegance',
#   'Gle 3.0 350',
#   'E 230 Mt',
#   'C Kompressor 1.8',
#   'C 180 At',
#   'E 2.0 Amg',
#   'C 1.8 ',
#   'A 1.4 A',
#   'Gla 1.4 Gla',
#   'Glb 1.4 Amg',
#   'Gls 500 4.7',
#   'E 2.0 Cabrio',
#   'C 1.8 C180',
#   'Glk 3.4 4matic',
#   'Glc 250 2.0',
#   'C 1.5 C200',
#   'B B 180',
#   'A 1.6 200',
#   'B 1.6 Blueefficiency',
#   'E 3.5 6v',
#   'Glc 350e A',
#   'C 2.8',
#   'E 2.0 Avantgarde',
#   'C C180',
#   'A 200 At',
#   'Glc 250 Coupe',
#   'C [c205] Coupe',
#   'Gle 3.0 4matic',
#   'Glk 3.0 4matic',
#   'Glc 2.0 Glc',
#   'Glc 4matic',
#   'C 200 1.8',
#   'E 200 Cgi',
#   'C 3.5 C',
#   'E 250 Cgi',
#   'C 3.0 Amg',
#   'C 200 2.0',
#   'Gl 500 4.7',
#   'A 1.4 Amg',
#   'B 180 1.6',
#   'Cla 1.3 Amg',
#   'Gle 3.0 Amg',
#   'Glk 3.0 300',
#   'Gle 2.2 Cdi',
#   'C 2.0 T',
#   'E 2.0 W212',
#   'Cla 180 Amg',
#   'Gle 2.2',
#   'Cla Amg Line',
#   'C 1.8',
#   'A 200 1.3',
#   'C 1.8 200',
#   'Glc 2.2 Cdi',
#   'B 2.0 Turbo',
#   'Gl 4.7 450',
#   'C 1.6 T',
#   'Glb 200 1.3',
#   'C 1.6 Limited',
#   'Gla 1.6 200',
#   'Glk 2.2 Cdi',
#   'Gl 4.7 500',
#   'Gle 250 Cdi',
#   'C Coupe ',
#   'C 1.6 Berlina',
#   'Gla 200',
#   'B 1.6 200',
#   'C 1.6 Cgi',
#   'A 1.4 Turbo',
#   'E 3.2 W124',
#   'Gla 1.6 X156',
#   'Glb 1.3 200',
#   'Gle 250 2.2',
#   'Glb Amg Line',
#   'Slk 200 1.8',
#   'C 2.8 Elegance',
#   'E 200 1.8',
#   'E 250 1.8',
#   'Cla 1.3 Cla',
#   'C C 43',
#   'Gls 4.7 4matic',
#   'Gls 450 3.0',
#   'Glc 2.0',
#   'Glc 2.2 220d',
#   'Gla Amg 4matic',
#   'Gla 200 1.6',
#   'A 200 1.4',
#   'C 200 Kompresor',
#   'A 1.3 A',
#   'A 1.6 A200',
#   'Gle 3.0',
#   'A 2.0',
#   'C 180 Kompressor',
#   'C 1,8 Kompressor',
#   'B 1,4 Progressive',
#   'Cla 1.6 Cla200',
#   'Glk 300 4matic',
#   'C 2.2',
#   'Cla 180 1.3',
#   'A 200 Amg',
#   'E 2.0 E',
#   'E 320 3.2',
#   'C 3.2',
#   'Gla 1.6 T',
#   'Gla 1.6 ',
#   'Glb 1.4 X427',
#   'Cla 1.6 Cla',
#   'E 2.0 250',
#   'Gl 4.7 4matic',
#   'A Progressive At',
#   'C 1.8 200k',
#   'Cla 1.3 Turbo',
#   'C 1.6',
#   'B 1.7 180',
#   'Cla 1.3 180',
#   'C 300 Amg',
#   'C C250 Amg',
#   'Cla 200 1.3',
#   'C 2.0 C',
#   'C 1.5 200',
#   'Glc 4matic Coupe',
#   'Glc 220d 2.2',
#   'Glk 3.0 Premium',
#   'Glb 1.6 Amg',
#   'E Amg Line',
#   'Gla 1.6 Turbo',
#   'Gla 200 1.3',
#   'Gla Amg',
#   'Cla At 1.6',
#   'Gla Gla 200',
#   'E E 250',
#   'C 6.3 Amg',
#   'G 4.0 Amg',
#   'E 3200',
#   'Gle 350d Amg',
#   'A [w176] Tp',
#   'Cla 2.0 Amg',
#   'C C 200',
#   'C C 180',
#   'C 1.6 Kompressor',
#   'E [w212] [fl]',
#   'Gl 4.7',
#   'C 1.6 Urban',
#   'Gla 1.3 ',
#   'Gle 3.0 Gle',
#   'C 1.8 Kompressor',
#   'A A 200'],
#  'C3': ['C3  ',
#   '1.4 Sx',
#   '1.6 Shine Automática',
#   '1.6 Feel Automática',
#   '1.6 1 Shine',
#   '1.6',
#   '1.6 Shine Aut',
#   '1.2 Vti Confort',
#   '1.2 Turbo Unique',
#   'Feel At',
#   '1.4',
#   '1.2 Unique At'],
#  'Prado': ['2.7 Sumo',
#   '2.8 Tx-l Diesel',
#   '4.0 Tx-l',
#   '3.0 Txl Diesel',
#   '2.7 Tx Fl',
#   'Txl',
#   '3.4 Vx Mt',
#   '3.0 Tx-l',
#   '3.0 Tx',
#   '3.0 Tx-l Fl',
#   '2.8',
#   '2.8 Tx-l Blindaje',
#   '3.0 Tx Blindaje',
#   '3.0 Tx Fl',
#   '3.0 Vx Fl',
#   '4.0 Vx Fl',
#   '4.0 Vx',
#   '4.0 Tx Fl',
#   '3.4 Vx',
#   '3.0 Txl',
#   '3.0 Vx Diesel',
#   '3.0 Txl 2019',
#   '2.7 Sumo Ego',
#   '2.7 Sumo Cruiser',
#   '2.7 Tx Sumo',
#   '4.0 Tx',
#   'Sumo',
#   '2.8 Tx-l Euro',
#   '3.4 Vx ',
#   '4.0 Tx Ambission',
#   '2.8 Tx-l 4x4',
#   '2.8 Tx-l At6',
#   '3.0 Tx-l Diesel',
#   '3.0 Tx Automática',
#   '2.8 Tx-l',
#   '3.0 Vx',
#   '2.8  Tx-l',
#   '2.7 Select',
#   '3.0 Vxl',
#   'Txl 3.0cc At',
#   'Sumo Tlx',
#   'Vx',
#   '2.8 Txl Diesel',
#   '2.8 Diésel Tx-l',
#   '3.0 Tx 4x4',
#   '4.0 Tx-l Fl',
#   '4.0 Tx At',
#   'Vxa',
#   '3.0 Vx-l Land',
#   '2.7 Txl Sumo',
#   '4.0 Tx-l Gasolina',
#   '3.0 Txl 4x4',
#   'Tx-l 3.0',
#   '2.8 Txl Blindaje',
#   '3.0 Tl-x',
#   '3.0 Gx Diesel',
#   '4.0 Tx-l 4x4',
#   '3.0 Txl At',
#   '2.7 Tx-l Sumo',
#   '2.3 Txl Euro',
#   '3.0 Land Cruiser',
#   '3.0 Tx L',
#   '3.4 Vxa',
#   '3.4 Vx Blindaje',
#   '2.8 Tx 4x4',
#   'Toyota Prado 4.0',
#   '3.0 Tx Ambission',
#   '3.0 Tx At',
#   '4.o Tx-l',
#   '2.7 Sumo Mt',
#   '4.0 Txl',
#   '2.7 Sumo Unlimited',
#   '3.0 Tx Diesel',
#   '4.0 Tx-l Blindada',
#   '2.7 Gx',
#   '3.0 Tx-l (fl',
#   '2.7 Sumo Gx',
#   '3.0 Tx-l Ii',
#   '2.8 Txl',
#   '3.0 Tx Diésel',
#   '2.4 Tx-l',
#   '2.8 Sumo',
#   '4.0 Vx Blindaje',
#   '2.8 Tx-l Black',
#   '3.0 Tx Blindada',
#   '2.8 Tx-l F2',
#   '3.0 Tx-l Blindaje',
#   'Tx',
#   '3.0 Limited Version',
#   'V8 Automatica 4x4',
#   '2.8 Vx At6',
#   '3.0 Diesel',
#   '4.0 Tx-l 7',
#   '4.0 Tx Blindaje',
#   'Tx-l At 3000cc'],
#  'Duster': ['2.0 Dynamique 4x2',
#   '2.0 Dynamique Mt',
#   '2.0 Dynamique Intens',
#   '1.6 Dynamique',
#   '2.0 Intense',
#   'Iconic',
#   'Intens Turbo',
#   '1.3 Intense Cvt',
#   '2-0 Dynamique',
#   '2.0 Polar Dynamique',
#   '2.0 4x4 Mt',
#   '1.6 Dynamique Mt',
#   '1.6 Expression Mecánica',
#   'Dynamique',
#   '1.6 Expression/zen Mt',
#   '2.0 Dynamique',
#   'Oroch Intens Outsider',
#   '1.3 Iconic 4x2',
#   '1.6 Expression Treck',
#   '1.6 Zen',
#   '2.0 Dynamique 4x4',
#   '2.0',
#   '1.3',
#   '2.0 Mt',
#   'Oroch 1.3 Zen',
#   'Duster Dynamique',
#   '1.3 Intens Mt',
#   'Oroch 2.0 Intens',
#   '1.3 Iconic Mt',
#   '1.3 Intense Mt',
#   '2.0 Tripadvisor',
#   '1.3 Intens 4x4',
#   '2.0 Dynamique 2013',
#   '1.6 Expression',
#   '2.0 Expression',
#   '1.3 Zen At',
#   '1.6 Intense Mt',
#   '1.6',
#   '2.0 Dynamique/ Intens',
#   '2.0 Dinamique 4x4',
#   '1.6 Zen Mt',
#   '1.3 Intens',
#   '2.0 Automatic',
#   'Oroch 2.0 Dynamique',
#   '2.0 Dinamique Dakar',
#   'Expression/zen',
#   '1.6 Expression Mecanica',
#   'Expression',
#   'Iconic 1.3 Turbo',
#   '1.3 Turbo Iconic',
#   '1.6 Expression Mercánica',
#   '1.3t Intense 4x4',
#   '1.6 Dynamique Intens',
#   '1.6 Expression/ Zen',
#   'Oroch 1.3 T',
#   'Oroch 2.0 Zen',
#   '1.6 Dynamique 4x2',
#   '2.0 Dynamique At',
#   '1.6 Intense',
#   '1.3 Iconic Turbo',
#   '2.0 Tripadvisor Intens',
#   '2.0 Polar At',
#   '2.0 Dynamique /',
#   '1.3 T Iconic',
#   '1.3 Turbo Intens',
#   '1.6 Expression Mt',
#   '2.0 Polar',
#   '2.0 Dynamique/intens Mt',
#   '2.0 Intens Mt',
#   '2.0 Intens',
#   'Oroch Intens Oudsider',
#   '1.3 Zen',
#   'Oroch 1.4 Outsider',
#   '1.6 Intens Mt',
#   '1.6 Expression Automática',
#   '2.0 Dynamique Dakar',
#   '1.3 Turbo 4x2',
#   'Oroch 1.3 Intens',
#   '1.3  Iconic',
#   '1.6 Intens',
#   '1.3 Intens Cvt',
#   'Oroch 1.3 Intents',
#   '2.0 Dynamique/intents 4x4'],
#  'X1': ['1.5 Sdrive 18i',
#   '2.0 Sdrive20i',
#   '2.0 Sdrive20i 2022',
#   '2.0 F48 Sdrive',
#   '1.5 F48 Sdrive',
#   'Paquete  M',
#   '3.0 Xdrive 28i',
#   '2.0 Sdrive 18d',
#   '2.0 E84 Sdrive',
#   'Sdrive 20i Sportline',
#   '2,0m Edition Xdrive20i',
#   '[f48] Sdrive 20i',
#   '2.0 Xdrive20i Paquete',
#   '3.0 E84 Xdrive',
#   '1.5 Sdrive18i',
#   '2.0 E84 Xdrive',
#   '3.0 Xdrive 25i',
#   'Sdrive 18 I',
#   '1.5 M Sdrive',
#   '2.0t Sdrive20i',
#   'Sdrive20i X Line',
#   '2.0 F48 Sdriver',
#   '1.5  Sdrive',
#   '2.0 Sdrive 20i',
#   '2.8 Sdrive 18d'],
#  'Optra': ['1.8 Hb',
#   '1.8 Advance',
#   '1.4',
#   '1.6 Advance',
#   '1.4 Mecanico',
#   '1.6 L Mt',
#   '1.8 Advance At',
#   '1.8 Lt Hatchback',
#   '1.8 Limited Mecánica',
#   '1.4 L',
#   'Advance',
#   'Limited 1800',
#   '1.6 Advance Mt',
#   '1.8 Limited At',
#   '1.8 L',
#   '1.6'],
#  'Vitara': ['1.6l',
#   '1.6 Gl',
#   '1.6 Live',
#   '1.6 Glx All',
#   '1.6 Glx +',
#   'Life Mt 1.6',
#   'Live',
#   '1.6 Gl Aut',
#   '1.6 2wd At',
#   '1.6 Gl Live',
#   '1.6 Gt',
#   '1.6 Gl All',
#   '1.6 4x4',
#   '1.6 Mt',
#   '1.6v Standar',
#   'Standar 16v',
#   '1.6 Live 2wd',
#   '1.4 Gl All',
#   'Glx + All',
#   'Gl',
#   '1.6 Live At',
#   '1.6 Live All-grip',
#   '1.6 Live All',
#   '1.6 Gl At',
#   '1.6 Gl ',
#   '16v Mt',
#   '1.6',
#   'All-grip 1.4 Boosterjet',
#   '2wd 1.6 Gl'],
#  'Fiesta': ['1.6 Hatchback',
#   '1.6 Titanium Hb',
#   '1.6 Se',
#   '1.6 Se Sportback',
#   '1.6 Sportback Titanium',
#   '1.6 Sportback Se',
#   '1.6 Hatchback Mecánica',
#   '1.6 Sportback Mecánica',
#   '1.6 Titanium At',
#   '1.6 Hatchback Titanium',
#   'Sportback Titanium',
#   'Titanium',
#   'Hatchback Se',
#   '1.6 Hatchback Se',
#   '1.5 Hatch Back',
#   '1.6 Titanium',
#   'Hatch Back Titanium',
#   'Sportback Se',
#   'Sportback Titanium At',
#   'Titanium Tp',
#   'Sportback',
#   '1.6 Sportback At',
#   'Se 1.6',
#   '1.6 Sportback Automática',
#   'St 1.6 Hatchback',
#   '1.6 Se Mt',
#   'Hatchback Titanium Mt',
#   '1.6  Sportback',
#   '1.6 Titanium Sedan',
#   '1.6 Se At',
#   '1.6 Hatchback Mecánico',
#   '1.6 Hatchback St',
#   '1.6 Hb Titanium'],
#  'Kyron': ['2.0 M200 Xdi', '2.3 G23 M230', '2.3 M230', '2.3 G23'],
#  'Tracker': ['1.8 Ltz Awd',
#   '1.8 Ls Mt',
#   '1.8 Lt Automática',
#   '1.8 Ltz',
#   '1.2 Premier Turbo',
#   'Turbo Premier',
#   'Ls',
#   '1.8 Ls',
#   '1.8 Lt At',
#   '1.8 Ls Mecánica',
#   '1.8 Lt',
#   '1.4 Lt 4x2',
#   '1.2 Turbo Ltz',
#   '1,8 Ls',
#   '1.8 Ls 2017',
#   '1.8 Ls 2018',
#   '1.8 Ltz At',
#   '1.8',
#   '1.8 Lt 4x2',
#   '1.2 Ltz',
#   '1.2 Ls Turbo',
#   '1.8 Ls At',
#   '1.8 Ls Automática',
#   '1.6 Ls',
#   '1.8 Premier 4x4',
#   '1.8 Lt 4x4',
#   '1.2 Ltz At',
#   '1.8 Ltz 4x4',
#   '1.2 Turbo Ls',
#   '1.2 Premier',
#   '1.8 Ls 4x2',
#   '1.8 Lt Mt',
#   'Lt',
#   '1.2 Lt Turbo',
#   '1.2 Ls'],
#  'Compass': ['Longitude',
#   '2.4 Limited 4x4',
#   '2.4 Limited',
#   '2.4 Longitude 4x2',
#   '2.4 Limited 2011',
#   '2.4 4x2 Sport',
#   '2.4 Sport',
#   '2.4 4x2 Longitud',
#   '2.4 Sport Mt',
#   '1.3 T270 Overland',
#   '2.4 Sport 4x4',
#   '2.0',
#   '2.4 Longitud Aut',
#   '2.4',
#   '2.4 Longitude At',
#   '2.4 At',
#   'Longitude Turbo'],
#  'Swift': ['Hybrido Mt 1.2',
#   '1.2 Live',
#   'Live 1.2l',
#   '1.2 Dzire',
#   '1.2 Hybrid',
#   'Hybrido',
#   '1.3 Mt',
#   '1.2 Hibrido',
#   '1.2 Dzire Mt',
#   '1.2 Híbrido',
#   '1.4 Gl',
#   '1.2 Gl',
#   '1.2',
#   'Hibrid 1.2',
#   '1.2 Hibrido Mt',
#   '1.2 Japonés',
#   '1200cc  Hybrid',
#   '1.2 Hybrido',
#   '1.1 Mt',
#   'Live',
#   '1.2 Dzire Gl',
#   '1.3',
#   '1.2 Hybrido Mt',
#   'Dzire Tam',
#   '1.6 Automatico',
#   '1.2 Drize',
#   '1.2  ',
#   '1.2 Live Mecanico',
#   'Hybrid Mt 1200cc',
#   'Dzire',
#   'Dzire Mt'],
#  'Captiva': ['2.4 Sport 182',
#   '2.4 Sport 169',
#   '2.4 Sport 4x2',
#   '3.0 Sport 4x4',
#   '3.0 Sport',
#   '2.4 Sport At',
#   '2.4 A Sport',
#   '3.0 Sport 4x2',
#   '2.4 Sport',
#   '1.5 Turbo Lt',
#   '1.5 Lt/ltz Turbo',
#   '1.5 Premier Turbo',
#   '2.4 Sport F.e',
#   '1.5  Lts',
#   '1.5 Lt',
#   '3.6 Sport',
#   '2.4 Sport Ls',
#   'Premier',
#   'Premier Turbo ',
#   'Sport',
#   '1.5 Premier',
#   'Lt Turbo',
#   '1.5 Lt/ltz',
#   '1.5  ',
#   '1.5 T Premier',
#   '3.2 Ltz',
#   '2.4 Sport 4x4',
#   'Lt 1.5 Turbo',
#   'Lt Turbo ',
#   '1.5 Lt Turbo',
#   '3.0 Sport At',
#   '1.4 Lt',
#   '3.0 S Port',
#   'Sport At 2.4',
#   '3.0 Sport Awd',
#   'Ltz',
#   'Captiva Premier Turbo',
#   '3.2 Next',
#   '3.2 C100 4x4',
#   '1.5t Premier 7',
#   'Sport 2.4 Sport'],
#  'Captur': ['2.0 Intens 4x2',
#   'Zen Mt',
#   '2.0 Zen Mecánica',
#   '2.0 Intens',
#   'Intens',
#   '2.0 Intens Automática',
#   '2.0 Intens At',
#   'Intens Tp',
#   '2.0',
#   'Bose Intense',
#   '2.0 Intense At',
#   '2.0 Zen At',
#   '2.0 Zen Mt',
#   '1.3 T Iconic'],
#  'Kwid': ['1.0 12v',
#   '1.0 Outsider',
#   'Iconic',
#   '1.0 Outsider Mt',
#   '1.0 Life',
#   '1.0 Outsader',
#   '1.0 Iconic',
#   '1.0',
#   'Zen',
#   '1.0 Kwid Mt',
#   '1.0 Intens Mt',
#   '1.0 Mt',
#   '1.0 Iconic Mt',
#   '1.0 Zen',
#   'Life',
#   'Outsider Mt 1000cc',
#   'Outsider',
#   '1.0 Zen Mt',
#   '1.0 Zen Mecánico',
#   '1.0 Intens'],
#  'Xv': ['2.0 20i Cvt',
#   '2.0i',
#   '2.0i Limited',
#   '2.0',
#   '2.0 Is Cvt',
#   '2.0i Cvt At',
#   '2.0i S ',
#   '2.0 Eyesight Hybrid',
#   '2.0i Limited Eyesigth',
#   '2.0i- S Es',
#   '2.0i-s Es Cvt',
#   '2.0l',
#   '2.0 Sport At',
#   '2.0 Cvt Symmetrical',
#   '2.0 Cvt',
#   'Hybrid',
#   'Limited Eyesight ',
#   '2.0i Style',
#   '2.0l-s Cvt Awd'],
#  'Forester': ['2.5 Sport At',
#   '2.0 Xt',
#   '2.0 Adw',
#   '2.5 Eyesight',
#   '2.5 Sport',
#   '2.0  At',
#   '2.5 Xs Limited',
#   '2.5 Awd Xs',
#   '2.5 Xs',
#   '2.0 Ls Es',
#   '2.5 Cvt Sport',
#   '2.0 Elite Hybrid',
#   '2.0',
#   'Elite Hibrida',
#   '2.0 Cvt Premium',
#   '2.0 Oa 4x4',
#   'Xs Limited',
#   '2.0 Cvt',
#   '2.0 X',
#   '2.0 X Mt',
#   '2.0 Premium At',
#   '2.0 Awd Oa',
#   '2.0l-s Es Elite',
#   '2.0l-l Cvt Premium',
#   '2.0 Xt Cvt',
#   '2.5 Advance'],
#  'Golf': ['1.8 Gl',
#   'Tsi Comfortline',
#   '1.4 Tsi Trendline',
#   '2.0 Gti Dsg',
#   '1.8 Manhattan',
#   '1.4 Tsi Comfortline',
#   '1.6 Highline',
#   '2.0 Tdi Sportwagen',
#   '2.0 Gti Performance',
#   '1.6 Trendline',
#   '1.4  Tsi',
#   'Trendline',
#   '1.6 Comfortline Mt',
#   '2.0 Mk 4',
#   '1.0 Plus'],
#  'Escape': ['2.5 Se Hev',
#   '2.0 Se 4x4',
#   '3.0 Xlt At',
#   '2.0 Se Tp',
#   '2.0 Se',
#   '2.0 Titanium Tp',
#   '3.0 Xlt',
#   '2.0 St Line',
#   '2.0 Titanium 4x4',
#   '2.0 St -',
#   '2.5 Sel Hev',
#   '2.0 Se 4x2',
#   '2.0 Titanium',
#   '2.5 Se Hybrid',
#   '2.0 Titanium 245',
#   '2.5 Se',
#   '2.0 Se 245',
#   '2.0 Titanium 240',
#   '3.0 Xls 2012',
#   'Titanium',
#   'Se 4x2',
#   '2.0 Se Turbo',
#   'St-line',
#   'Titanium Hev',
#   '2.5 Hev 4x4',
#   '2.0',
#   '2.0t Titanium',
#   'Se 4x4',
#   '2.5 Hev',
#   '2.0 Se 240',
#   'Se',
#   '2.5 Titanium Hev',
#   '2.0 Se Ecoboost',
#   '2.0 Titanium Ecoboost',
#   '2.0 Titanium At',
#   '2.5 Platinum Hibrido',
#   '2.5 Platinum ',
#   '2.5 Titanium',
#   '3.0 Xlt ',
#   '2.0 Titanium 245hp',
#   '2.0 Platinium Ecoboost',
#   '2.0 St-line',
#   'St - Line-4x4',
#   '3.0',
#   '2.5 Titanium Hybrid',
#   '2.5 Se Hibrida',
#   '2.0 Titanium 4x2',
#   '2.5 Titanium Hibrido',
#   '2.0 Turbo Se',
#   '2.0 Titamium',
#   'Se Tp 2000cc',
#   '2.5 Escape Se',
#   '3.0 Xlt 4x4',
#   '3.0 Xls',
#   '2.0 Sel Hev',
#   '2.0 Se Hev',
#   'Titanium Tp 2000cc'],
#  'Cross': ['Up 1.0 Mt', 'Up 1.0l', 'Trek 2.0 Limited', 'Trek 2.0 I-l'],
#  'Luv': ['2.4 Dmax Estacas',
#   '2.5 D Max',
#   '2.2 Basica Tfr',
#   'Tfr',
#   '3.0 D-max Ls',
#   'Dmax',
#   '2.3 Dlx Tfr',
#   '2.4 D-max',
#   '2.4 Dmax',
#   '1.6 Std Tfr',
#   '2.3 Std Tfr',
#   '3.5 D-max Doble',
#   'Basica',
#   '3.0 Dmax 2',
#   '2.5 Dmax Diesel',
#   '2.5 Dmax 2',
#   '2.5 Dmax',
#   '1.6 Kb 41',
#   '3.0 Dmax 4x4',
#   '2.5 4x2',
#   '2.5 Dmax Mt',
#   'D-max 2.5 Dsl',
#   '3.0 4x2',
#   '2.5 Ls Tfr',
#   '2.3 Estacas',
#   '3.2 Ls Tfs'],
#  'Qashqai': ['2.0 4x2 Mecánico',
#   '2.0 Exclusive',
#   '1.6l 2wd',
#   '2.0',
#   '1.6 4x2',
#   '2.0  Exclusive',
#   'Exclusive',
#   '2.0 Exclusive 142',
#   '2.0 Exclusive 4x4',
#   '2.0l 2wd',
#   '2.0 2wd Tp',
#   '2.0 Sense',
#   '2.0 Sense 142',
#   '2.0 Advance 140',
#   '2.0 Exclusive ',
#   '2.0l 4wd',
#   '1.6',
#   '2.0 Exclusive 140',
#   '1.6 Mt 4x2',
#   '2.0 Sense 140',
#   '2.0 +2 4x2',
#   '2.0l Awd 4x4',
#   'Wagon',
#   '2.0 2wd +2',
#   '2.0 4x2',
#   '2.0 Advance 142',
#   '2.0 Advance',
#   '2.0 At',
#   '1.3 Exclusive',
#   '2.0 2wd At',
#   '2.0 Xtronic Cvt',
#   '2.0l Exclusive 4x4',
#   '2.0 Advance At',
#   'Sense Tp 2.0'],
#  'Onix': ['1.0t Rs Mt',
#   '1.0 Ltz Turbo',
#   '1.0 Ltz',
#   '1.4 Ltz 4',
#   '1.0 Premier',
#   'Premier',
#   '1.0t Mecánica',
#   '1.0 Lt At',
#   '1.4 Active',
#   '1.0 Turbo Hatch',
#   'Ltz 5 P',
#   '1.0 Rs Turbo',
#   '1.0 Lt Tp',
#   '1.4 Activ',
#   '1.0 Lt',
#   '1.0 Lt Turbo',
#   'Lt Turbo',
#   '1.0 Rs',
#   '1.0t Automática',
#   'Ltz Turbo',
#   '1.4 Lt',
#   '1.0 Lt (turbo)',
#   '1.0 Turbo Lt',
#   '1.4 Ltz 5',
#   'Ltz Automatico',
#   '1.4 Ltz Aut',
#   '1.4 Ltz Mt',
#   '1.4 Ltz',
#   '1.4 Ltz At',
#   '1.0t Ltz At',
#   'Rs Turbo 1.0',
#   '1.0t Lt At',
#   '1.0t Automática Premier',
#   '1.0 Turbo Premier',
#   '1.0 Rs Mt',
#   '1.0t Lt Mt',
#   '1.0 Mecanico',
#   '1.0 Premier Automática',
#   'Premier 1.0',
#   'R/s Mt'],
#  'Logan': ['1.6 Dynamique',
#   '1.6 Expression',
#   '1.6 Privilege /',
#   '1.6 Life',
#   '1.6 Expression Fii',
#   '1.4 Entry Familier',
#   '1.6 Dynamique Fii',
#   '1.6 Privilege Mt',
#   '1.6 Authentique /',
#   'Life 1.6',
#   'Intens',
#   '1.6 Intens',
#   'Dynamique',
#   '1.6 Dynamique Full',
#   '1.6 Authentique',
#   'Zen',
#   'Intens Full Equipo',
#   '1.6 Expression /',
#   'Life Plus',
#   '1.4 Familier',
#   '1.4 Familier Mecánico',
#   'Expression',
#   '1.6 Dynamique Nd',
#   '1.6 Polar',
#   'Intense/privilege',
#   '1.6 Mt',
#   '1.6 Privilege',
#   'Polar / Life',
#   'Life 1.6 Mt',
#   '1.6 Expression Mt',
#   '1.6',
#   'Polar',
#   '1.6  Dynamique',
#   '1.6 Authentique Mt',
#   '1.6 Expression Nigth',
#   '1.6 Expression At',
#   '1.6 Expression Day',
#   '1.4 Familier Mt',
#   '1.6 Authentic Mt',
#   '1.6 Intens Mt',
#   '1.6 Expression Mecanico',
#   '1.6 Authentique Life',
#   '1.6 Privilige Intens',
#   '1.6 Intense Mt',
#   '1.4 Dinamique',
#   '1.6 Anthentique',
#   '1.6 Intens Cvt',
#   'Familier 1.4 Mt',
#   'Family',
#   '1.6 Intens Version',
#   '1.6 Dynamique ',
#   '1.6 Life+',
#   '1.6 Intens At',
#   '1.6 Zen',
#   'Authentique/life',
#   '1.4 Expression',
#   'Expression/life',
#   'Authentique'],
#  'Tucson': ['2.0 Crdi Mecánica',
#   'Ix-35 2.0 Gl',
#   '2.7 Gls',
#   'Ix-35 2.0 Style',
#   'Ix-35 2.0l Crdi',
#   'Ix-35 2.0 Abs',
#   '2.0 Mt 4x4',
#   'Ix-35 2.0l 164',
#   'Premium Europea',
#   'Ix-35 2.0l',
#   'Crdi',
#   'Ix-35 2.0',
#   'Ix-35 2.0l 4x4',
#   '2.0 Gl Mt',
#   '2.0 Gl 4x2',
#   'Ix-35 2.0l 4x2',
#   'Ix-35 20l',
#   '2.0',
#   '2.0 Premium Europa',
#   'Ix-35 2.4 Secuencial',
#   'Nx Premier',
#   '2.0 Nx Advance',
#   '2.0 Gls',
#   '2.0 Gl Advance',
#   'Ix-35 2. Gls',
#   'Ix-35 2.0i Gl',
#   'Ix-35 2.0 4x4',
#   '2.7 Gls 4x4',
#   '2.4 Ix35 Gls',
#   'Ix-35 2.4 At',
#   'Ix-35 2.0l 156',
#   '2.0 New Tucson',
#   'Gl',
#   '2.0 Advance Europea',
#   'Advance Europea At',
#   'Ix-35 2.4l Gls',
#   '2.0 Gl Premium',
#   'Ix-35 2.4 Gls',
#   'Ix-35 2.0 Diésel',
#   'Ix-35 2.0 4x2',
#   '2.0 Gl',
#   'Ix-35 2.0 I',
#   '2.0 Nx 4',
#   'New Tucson 2.0',
#   'Ix-35 2.4l',
#   'Ix-35 Gl 2.0'],
#  'Allegro': ['1.3 1aln3m',
#   '1.6 323n6m',
#   '1.3',
#   '1.6 323h6m',
#   '1.6 Aln6m',
#   '1.6 1aln6m'],
#  'Sportage': ['2.0 Revolution Gasolina',
#   '1.6 Vibrant Hibrida',
#   'Zenith',
#   '2.0 At 4x2',
#   '2.0 Ex',
#   '2.0 Desire',
#   '2.0l',
#   '2.0 Zenith Aut',
#   '2.0 Vibrant',
#   '2.0l 4x2',
#   '2.0 Lx',
#   '2.0 Lx 2007',
#   '2.0 Emotion Aut',
#   '2.0 20l Diesel',
#   'New Sportage 2.0',
#   '2.4',
#   '2.0 Fq Mecánica',
#   'Lx Suma',
#   'Revolution 2.0',
#   '2.0 Revolution 4x2',
#   '2.0 Zenith 4x2',
#   '2.4 Revolution 4x4',
#   '2.0 Vibrant Aut',
#   '2.0 Lx At',
#   'Vibrant',
#   '2.0 Emotion',
#   '2.0 Gasolina',
#   '2.0 Revolution Diésel',
#   '2.0 Ice',
#   '2.0 Diésel',
#   'Lx',
#   '1.6 Vivrant Hybrid',
#   '2.0 Desire Aut',
#   '2.0',
#   '2.4 Revolution',
#   '2.0l Gasolina 4x2',
#   'New Sportage Lx',
#   '2.0 Vibrant At',
#   '2.0 Revolution',
#   '2.0 Revolution At',
#   '2.0 Summa',
#   '2.0 Cvvt',
#   '2.0 Gt Line',
#   'Gt 2.0l Gt',
#   '2.0 Revolution Lx',
#   '2.0 Fq',
#   '2.0 Zenith',
#   '2.0 Revolution Summa',
#   '1.6 Desire Hibrida',
#   'Gt Line 2.0',
#   '2.4 Ex',
#   '2.0 New Sportage',
#   '2.4 Revolution At',
#   '2.0 Fq 4x4',
#   '2.0l Lx 4x2',
#   'Fq 2.0l At',
#   '2.0l Fq',
#   '2.0  Revolution',
#   '2.0 Ex Vibrant',
#   '2.0 Lx 4x2',
#   '2.0 Nq5 Desire',
#   'Fq',
#   '1.6 Vibrant At',
#   '2.0 Desire At',
#   'New Sportage Ex'],
#  'Hilux': ['2.4l',
#   '2.4l 4x4',
#   '2.8l',
#   '4x4 2.7 Srv',
#   'Doble Cabina',
#   'Ex',
#   '2.7 Est',
#   '2.7 Imv 4x2',
#   '2.7',
#   '2.5 Doble Cabina',
#   '2.5 D-4d',
#   '2.5 Imv Mt',
#   '2.7 Vvt-i',
#   '2.8 Srv Diesel',
#   '2400',
#   '4.0',
#   '2.5 Imv 4x4',
#   '2.5 Imv 4x2',
#   '2.8',
#   '4x4',
#   '2.8 Srx',
#   '2.4 Doble Cabina',
#   '2.5 Imv Diesel',
#   '2.7 Vigo',
#   '2.5 Diésel 4x2',
#   '2.7 Estacas',
#   '2.4 Et',
#   '2.4 Estacas 4x2',
#   '2.4 Srv 4x4',
#   '2.5 Vigo',
#   '2.7 Imv 4x4',
#   '2.5 4x4',
#   '3.0 4x4',
#   '2.5 Sr5 Turbo',
#   '3.0 Vigo',
#   '3.0 Srv 169',
#   '2.5 Diesel Mecanico',
#   '24l At 2400cc',
#   '2.8 4x4 Srv',
#   '2.7 Sr 4x4',
#   '2.7l',
#   '2.5 Vigo 4x4',
#   '2.8 4x4 Diésel',
#   '2.4 Diésel 4x4',
#   '2.8l Srv',
#   '2.7 4x4',
#   '2.8 Srx Diesel',
#   '3.0 Srv',
#   'Ivt Mt 2.5',
#   '2.8 Srv',
#   '2.8 Srv 4x4',
#   '2.7 4x4 Mt',
#   '2.8 Diesel',
#   '4.0 Srx At',
#   '2.5 Imv 142',
#   '3.0 Srv 4x4',
#   '2.5 Et 4x2',
#   '2.7 Mt 4x2',
#   '2.7 Imv Mt',
#   '4.0l',
#   '2.4 Es',
#   '2.7 4x2',
#   '2.4 4x4 Mt',
#   '2.4 Eu',
#   '2.8 L Diesel'],
#  'Parati': ['1.8 Parati'],
#  'Cerato': ['Forte Sx',
#   'Vivro',
#   'Forte 2.0 Sx',
#   'Pro 1.6l',
#   '1.6 Sx',
#   '2.0 Lx',
#   'Pro 1.6 Ex',
#   'Pro Sx',
#   '1.6 Vivro Vibrant',
#   'Pro 1.6',
#   'Pro 1.6 Zenith',
#   'Forte 1.6 At',
#   'Pro Cerato Pro',
#   'Forte 1.6',
#   'Koup Race Ex',
#   'Pro 1.6 Sx',
#   'Forte 1.6 Lx',
#   'Pro 1.6 ',
#   '1.6l',
#   'Forte 1.6 Sx',
#   'Forte 2.0 Koup',
#   'Pro 1.6l 130',
#   'Forte 2.0',
#   'Pro Ex 1.6',
#   'Forte 1.6 Hb',
#   '1.6 Ex Ciclon',
#   '1.6 Forte Mt',
#   'Koup 2.0 Sx',
#   'Pro 1.6 Zhenith',
#   'Pro 1.6l Sx',
#   'Forte Koup Sx',
#   'Forte 1.6 Koup',
#   'Koup 2.0 Koup'],
#  '2.6': ['Montero Tradicional'],
#  'Rio': ['1.4 Vibrant Mt',
#   '1.25 Ub Ex',
#   '1.6 New Rio',
#   '1.4 Vibrant At',
#   '1.5 Stylus',
#   '1.4 Zenith',
#   '1.4 Emotion',
#   '1.25 4 P',
#   'Spice Ub Ex',
#   '1.25',
#   'Zenith',
#   'Xcite',
#   '1.4',
#   'Ub Ex',
#   '1.25 Ex Mt',
#   '1.2 5 P',
#   'Ubex',
#   '1.6 Vibrant Hb',
#   '1.4 4 P',
#   'Spice 1.4 Mt',
#   '1.4 Ex',
#   '1.4 Vibrant',
#   'Spice 1.2',
#   '1.4 Emotion Hb',
#   '1.4 Ub Ex',
#   '1.25 2018',
#   '1.4 Zenith At',
#   'Xcite 1.6',
#   'Spice R 1.4',
#   '1.5 Stylus Ls',
#   '1.3 Ub Ex',
#   '1.25 5 P',
#   'Spice R Summa',
#   '16 Sport',
#   'Ub Ex 1.4',
#   '1.5',
#   'Spice 1.4 Tp',
#   'Spice 1.5',
#   'Lx',
#   '1.2 Ub Ex',
#   '1,250 Spice',
#   '1.25 Spice',
#   '1.4 Vibrant Hb',
#   'Spice 1.4'],
#  'Murano': ['3.5 Exclusive',
#   '3.5 Awd Secuencial',
#   'Exclusive 2016',
#   '3.5 Sl',
#   '3.5 Sl Awd',
#   '3.5 Z52 Exclusive'],
#  'Rover': ['Range Rover Sport',
#   'Range Rover 2.0',
#   'Discovery 4 5.0',
#   'Evoque 2.0 Prestige',
#   'Range Rover Evoque',
#   'Freelander 2.0 Se',
#   'Freelander 2.0 Hse',
#   'Discovery Sport 2.5',
#   'Evoque 2.0 Si4',
#   'Range Rover Velar',
#   'Evoque Se At',
#   'Defender 3.0 First',
#   'Santana 2.6',
#   'Discovery 5 3.0',
#   'Freelander 3.2 Hse',
#   'Evoque 2.0 Turbo',
#   'Discovery Sport 2.0',
#   'Defender 3.0 Xs',
#   'Evoque 2.0 At',
#   'Evoque 2.0 Pure',
#   'Discovery 4.4 Lr3',
#   'Evoque 2.0 Dynamic'],
#  'Sail': ['1.4 Ls',
#   '1.4 Sport Ltz',
#   '1.4 Ltz',
#   '1.4 Ls Mecánica',
#   '1.4 Lt',
#   'Ls',
#   '1.4 Ltz Sport',
#   '1.4l Mecánica',
#   '1.4 Ltz Limited',
#   '1.4 Mecanico',
#   '1.4 Ltz Mt',
#   '1.4 Ltz 4',
#   '1.4 Ls Mt',
#   'Ls Mt 1400cc',
#   '1.4 Lt 4',
#   'Ls Mt 1.4',
#   '1.4 Ltz 5'],
#  'S-cross': ['1.4 Turbo Glx',
#   '1.4 Glx All',
#   '1.6 Gl 2wd',
#   '1.6 Gl',
#   'S Croos 2wd',
#   '1.4 Sx4 Turbo'],
#  'Xc90': ['B6 Momentum Hibrido', '2.0 T8 Awd', '2.0 T6 Awd', '2.0  Ultimate'],
#  'A4': ['1.8 Tfsi Comfort',
#   '1.8 Tfsi Ambition',
#   '2.0 Tfsi Ambition',
#   '1.8 Tfsi Multitronic',
#   '2.0 Tfsi Advanced',
#   '2.0 Tfsi Mhev',
#   '2.0 40 Tfsi',
#   '1.8 T',
#   '1.4 Tfsi Atraccion',
#   '1.8 Tfsi Luxury',
#   '1.8 Luxury',
#   '2.0 B9 Tfsi',
#   '2.0 T At',
#   '1.8 Turbo ',
#   '2.0 Tfsi Quattro',
#   '1.8 T Mt',
#   '1.8 Turbo B7',
#   '1.6 Full Equipo',
#   '1.8 B8 Tfsi',
#   '2.0 Ambition',
#   '1.8 T Luxury',
#   '1.8 Turbo',
#   '1.8 Dynamique',
#   '2.0 B6 Multitronic',
#   '2.0 Tfsi',
#   '1.8t B8 Tfsi',
#   'B6 1.8',
#   '2.0 Tfsi Luxury'],
#  'Cla': ['180 1.6', '180 Amg Line', '200 Limited Plus'],
#  'Beetle': ['Sport 2.5',
#   '2.5 Sport',
#   '2.5 Design',
#   '2.5  Spotr',
#   '2.5 Sport At'],
#  'Lancer': ['1.3 Gl 4',
#   '1.3 Gl 4p',
#   'Avanzado',
#   '1.3 Gl Fl',
#   '2.0 Avanzado',
#   '2.0 Gls',
#   '2.0 Advance Secuencial'],
#  'Escarabajo': ['1.6',
#   '1.6 Escarabajo',
#   'Beetle 1.6 Mt',
#   '1.3 Escarabajo',
#   'Escarabajo',
#   '1.6 Escarabajo Aleman',
#   '1.2 Gasolina',
#   '1.3'],
#  'Corolla': ['Cross 1.8 Hv',
#   'Cross 1.8 Se-g',
#   '1.8 Xe-i',
#   '1.6 Xli',
#   '1.8  Xl-i',
#   '1.8 Se-g Hibrido',
#   '1.8 Se-g',
#   '1.8 Seg',
#   '2.0 Xe-i',
#   '1.8 Xli Hibrido',
#   '1.8 Se-g Hybrid',
#   '1.8 Se -',
#   '1.8 Seg 2019',
#   '1.8 Xli',
#   '1.8 Gli At',
#   'Cross 2.0 Xe-i',
#   '1.8 Xe-i 4x2',
#   'Cross 1.8 Hev',
#   'Cross 2.0 Xei',
#   'Cross 1.8 Xe-i',
#   'Se-gat 2.0',
#   '1.6 Xli Mt',
#   'Cross 1.8 Xei',
#   '1.6 Se-g At',
#   'Cross Se-g Hybrid',
#   '1.8 Se-g Hibrida',
#   'Se-g Hibrido',
#   'Cross 1.8 Seg',
#   'Cross Xe-i Hybrid',
#   'Cross 1.8 At',
#   '1.8 Se-g At',
#   '1.8 Le',
#   'Cross 2.0 Gr-',
#   'Cross Se-g Hybrida',
#   '1.8 Se-g Hybrido',
#   'Cross 2.0 Se-g',
#   'Cross 2.0 At',
#   'Cross 2.0 Hybrid',
#   'Cross Se.g',
#   '1.8 Hev Seg',
#   '1.8 Gli',
#   '1.6 Xl',
#   'Cross Xxi Hybrid',
#   '1.8 Xei',
#   '1.8 Se-g Híbrido',
#   '2.0 Gr-s',
#   'Seg 1.8 Seg',
#   'Cross 1.8 ',
#   'Xl-i Hybrida',
#   '2.0 Xl-i Mecánico',
#   '2.0 Se-g',
#   'Xei',
#   '1.8 At Se-g',
#   'Cross Xe-i',
#   '2.0 Xl-i',
#   'Cross Se-g Hibrida'],
#  'Willys': ['3.7 Comando', '2.5'],
#  'Yaris': ['Sport',
#   'Xs',
#   '1.5 Xls Hibrida',
#   '1.5 Xs',
#   'Cross 1.5 Xls',
#   '1.5 Cross Xls',
#   'Cross',
#   '1.5 Xl',
#   'Cross Xs Hybrida',
#   '1.5 Xs Aut',
#   '1.5 S Aut',
#   'Cross Xls 1.5',
#   '1.5 Xs At'],
#  'Grand': ['Vitara 2.4 Glx',
#   'Vitara 2.4 Sz',
#   'Move 1.5 Mecanica',
#   'Vitara 1.6 Sz',
#   'Cherokee 4.7 Laredo',
#   'Vitara 2.7 Xl7',
#   'Vitara 1.6 Mt',
#   'Vitara 1.6 16l',
#   'Cherokee 3.6 Limited',
#   'Vitara 1.6 Grand',
#   'I10 1.0 Illusion',
#   'Vitara 2.4 At',
#   'Vitara 1.6 L',
#   'Vitara 2.7',
#   'Vitara 2.0 Sz',
#   'Vitara 2.5 Dohc',
#   'Vitara 1.6 Sport',
#   'Cherokee 3.6l Limited',
#   'Cherokee Limited',
#   'Vitara Sz',
#   'Pregio 3.0 Gs',
#   'C4 Picasso 1.6',
#   'Vitara 2.5 V6',
#   'Vitara 2.7 Sz',
#   'Cherokee 3.6 Laredo',
#   'Vitara 2.4',
#   'Cherokee 4.7 Limited',
#   'I10 Illusion 1.0',
#   'Vitara 2.0 L',
#   'Carnival Sedona 3.3',
#   'Vitara 2.5 4x4',
#   'Cherokee 4.0 Laredo',
#   'I10 1.25 Illusion',
#   'Scénic 2.0 Mt',
#   'Vitara 1.5 Glx',
#   'Move 1.6l',
#   'Vitara 2.5 At',
#   'Vitara 2.5',
#   'Cherokee 3.7 Laredo',
#   'Sedona 3.3',
#   'Vitara Xz Glx'],
#  'Symbol': ['1.4 Alize',
#   '1.6 Luxe',
#   'Ii Luxe',
#   'Authentique',
#   '1.4 Authentique',
#   '1.4 Expression',
#   '1.6 Fase Ii',
#   '1.6 Mt',
#   '1.6 Confort'],
#  'Qq': ['6 1.3 Mt'],
#  'Stepway': ['1.6 Zen',
#   '1.6 Intens',
#   '1.6l',
#   '1.6 Dynamique /',
#   '1.6 Dynamique',
#   'Automatico 1.6 Trek',
#   '1.6 Intense Automática',
#   '1.6 Intense',
#   '1.6 Intens Automatica',
#   '1.6 Polar',
#   '1.6 Intense Mecánica',
#   '1.6 Intense Cvt',
#   '1.6 Dynamique Automática',
#   '1.6 Mt Hb',
#   'Expression/zen',
#   '1.6 Intens Mt',
#   '1.6 Dynamique Mecánica',
#   '1.6 Intens At',
#   '1.6 Expression /',
#   'Dynamique Intens',
#   '1.6 Dynamique At',
#   'Dynamique Night And',
#   '1.6 Dynamique/intens Automático',
#   '1.6',
#   '1.6 Outdoor Mt',
#   '1.6 Trek Intens',
#   '1.6 Mt',
#   '1.6 Intens Automatico',
#   'Intense',
#   '1.6 Expression/zen Mt',
#   '1.6 Trek',
#   '1.6 Intens Cvt'],
#  'Fluence': ['2.0 Privilege', '1.6 Confort 2013', 'Privilege'],
#  'Sentra': ['1.6 B13',
#   '2.0 B16',
#   '2.0 Blindaje 2',
#   '2.0 S',
#   '2.0 Sr Exclusive',
#   '1.8 B17 Fl',
#   '1.8 B17 ',
#   '2.0 Sl',
#   '1.8 Pure Drive',
#   'Advance',
#   '2.0 Mt',
#   '1.6',
#   'At',
#   '1.8 B17 Exclusive',
#   'E',
#   '1.8',
#   '2.0',
#   '1.8 Sr 2018',
#   '2.0 E',
#   '2.0 E Automatico',
#   '1.6 Std',
#   '1.6 Sedan',
#   '2.0 At Sedan',
#   '2.0 Sl At',
#   '2.0 Exclusive Sr',
#   'B13',
#   '1.8 B17 Advance',
#   '1.8 Exclusive',
#   '1.8 Sense',
#   '2.0 E 2.0',
#   '2.0 Std',
#   '2.0 B18 Sr',
#   '1.8 Sr',
#   '1.8  Exclusive',
#   '1.6 B13 At',
#   '1.6 B13 Super',
#   'Exclusive Advance',
#   'Sense Fl At',
#   '1.8 B15',
#   '1.8 Exclusive At',
#   'Sense',
#   '2.0 B18 Sense',
#   '1.8 F48 Sdrive',
#   'B17 Sr',
#   '1.6 B14 Gxe',
#   'Se Advance 2.0'],
#  'F-150': ['6.2 Svt Raptor',
#   '3.5 Svt Raptor',
#   'Lariat',
#   '3.5 Lariat Sport',
#   '3.5 Xlt',
#   'Xlt At',
#   '3.3 Xlt',
#   '3.5 Platinum 4x4',
#   '3.5 Raptor Supercrew',
#   'Xlt',
#   'Svt Raptor',
#   '5.4 Xlt At',
#   '5.4 Fx4 At',
#   '5.4 4x4 At',
#   '3.5 Raptor',
#   '3.5 Platinum',
#   '3.5 Lariat',
#   '5.4 Fx4',
#   '3.5 Xlt Scab',
#   '5.0 Xlt 4x4',
#   '5.0 4x2 At'],
#  'New': ['Sportage Lx Revolution',
#   'Sportage 2.0 Lx',
#   'Elantra 1.6',
#   'Sportage 2.0 Ex',
#   'Koleos 2.5 Intens',
#   'Sportage Lx',
#   'Sportage Lx 2.0',
#   'Beetle 2.5 Sport',
#   'Koleos 2.5 Zen',
#   'Sportage 2.4 Revolution',
#   'Sportage 2.0 Revolution',
#   'Beetle 2.0',
#   'Koleos 2.5',
#   'Accent 1.6 Advance',
#   'Sportage 2.0 At',
#   'Beetle 2.5 Design',
#   'Beetle 2.5 Desing',
#   'Beetle Cabrio',
#   'Tucson Gl Premium',
#   'Sportage 2.0 Fq',
#   'Sportage Dynamax'],
#  'Silverado': ['5.3 Z71 4x4', '5.3', 'C10'],
#  'D-max': ['2.5 Doble Cabina',
#   '2.5 Estacas',
#   'Estacas',
#   '2.5 Mecanica 4x4',
#   'Ls Doble Cabina',
#   '2.5 Estacas 4x2',
#   '3000 3.0t Estacas',
#   '2.5l Mecánica 4x4',
#   '2.5 Crd Doble',
#   '2.5l Work',
#   '2.5 4x4 Diesel',
#   '2.4',
#   '3.0 Luv Diesel',
#   '2.5 Dsl',
#   '2.5 4x2',
#   '2.5 Luv Estacas',
#   'Cri 2.5 Td',
#   '2.5l Mecánica 4x2',
#   '3.0 Luv Estacas',
#   '3.0 4x4',
#   '3.0 Mt',
#   '3000 Estacas'],
#  'Song': ['Plus 1.5 Dm-i', 'Plus Dm-i 1.5', 'Plus 1.5 '],
#  'March': ['1.6 Advance',
#   '1.6 Active Mt',
#   '1.6 Active',
#   '1.6 Sense',
#   '1.6 Sense Connect',
#   '1.6 Sense Automatico',
#   'Sense At',
#   'Active',
#   'Advance 1.6',
#   '1.6 Drive',
#   '1.6 Sense At',
#   '1.6 Advance At',
#   '1.6 Sense Mt',
#   '1.6 Advance Mt',
#   '1.6 Hb At',
#   '1.6 Mt',
#   'Active Mt',
#   '1.6 Active Mecanico'],
#  'Vito': ['2.1 114 Cdi',
#   '114 Cdi Euro',
#   '2.1 114cdi Tourer',
#   '1.6 111 Tourer'],
#  'X-trail': ['2.5 At Full',
#   '2.5 Intelligent',
#   '2.5 Advance',
#   '2.5 Exclusive',
#   '2.5 S Basica',
#   '2.5 X Ltd',
#   '2.5 Exclusive Psj7',
#   '2.5 Advance Connect',
#   '2.5 T32 Exclusive',
#   '2.2 S Basica',
#   '2.5 4x4',
#   'Classic',
#   'T32 2.50 At',
#   'Exclusive',
#   '2.5 X',
#   '2.5 Kapital',
#   '1.5 E-power Hybrid',
#   'T32',
#   '2.5 T 31',
#   '2.5 Exclusive Secuencial',
#   '2.5 T30',
#   'T32 2.5 Exclusive',
#   'E-power Exclusive At',
#   '1.5',
#   '2.5 T32',
#   '2.5',
#   '2.5 Classic',
#   '2.5 Advance At',
#   '2.5 Exclusive 4x4',
#   '2.5 Exclusive Connect',
#   '2.5 Classic Mt',
#   '2.5 4x4 Lujo',
#   '1.5 T33 E-power',
#   'S Basica',
#   'Clasica Mecanica',
#   '2.5 I Kapital'],
#  'Fortuner': ['Sw4 Street',
#   '2.7  4x2',
#   '2.7l 4x2',
#   '2.4 Sw4 Street',
#   '2.7 Sw4',
#   '2.4 L',
#   '2.4 Sr Diesel',
#   '4.0 Sr',
#   '2.4',
#   '2.8 Srv Tp',
#   '3.0 Sr5',
#   'Srv',
#   '2.4 Srv',
#   '2.7l 4x2 At',
#   '2.8 Srv Diesel',
#   '2.7l',
#   '2.7',
#   '2.7 Gr',
#   '2.7 Urbana',
#   '2.7 Sw4 Street',
#   '2.7l 4x4',
#   '2.8l',
#   '2.4 Street',
#   '2.7 Srv 4x2',
#   '2.7 27l 4x2',
#   '4.0 Sr5',
#   'Sr5',
#   '2.7l Street',
#   '2.7 Sr5',
#   '2.4 24l Street',
#   '3.0 Turbo Diesel',
#   '2.4 Srv Diesel',
#   '2.8 L Diesel',
#   '2.4 Sr5 Urbana',
#   '3.0 Srv Diesel',
#   '2.4 Sr',
#   '2.4 At 4*4',
#   '2.7 Sr5 4x2',
#   '2.7l Mid',
#   '2.4 Diesel 4x2',
#   '2.4 Street 4x2',
#   '3.0 Sr5 Blindaje',
#   'Srv-5',
#   '2.7 Srv Gasolina',
#   '2.7 4x2 Mecanica',
#   '2.7 Urbana 4x2',
#   '2.4 Street At',
#   '2.4 4x2',
#   '2.8 Sr',
#   '2.7 Sr',
#   '2.8 Srv',
#   '2.7 Sr5 4x4',
#   '3.0 Srv 4x4',
#   '2.4 At Srv',
#   '2.4 Street Deesel',
#   '2.4 L Street',
#   '3.0 Sr5 160',
#   '2.4l Srv',
#   '2.7 Trd Especial',
#   '2.7 Srv',
#   '2.4i Sr 4x2',
#   '2.7 At',
#   '2.4l Sr',
#   '2.8 Sr Diesel',
#   '2.7 Urbana Sr5',
#   '3.0 Sr5 169',
#   '2.6 Urbana',
#   '2.4 At',
#   '2.7 Sr5 At',
#   '2.7 4x4 At',
#   '2.7 Mt 4x4',
#   '2.7 At Gasolina',
#   '3.0 Srv Mt',
#   '2.7 Streed',
#   '3.0 Diesel',
#   '2.8',
#   '2.4 Streed',
#   '2.4l Street',
#   '2.4l Street Diesel',
#   '3.0 Srv',
#   '2.7 Urbana Mt',
#   '2.4 24l',
#   '2.7 4x2',
#   'V6 4.0 Sr5',
#   '2.7l Mid 4x2'],
#  'N300': ['1.2 Cargo',
#   'Van Carga',
#   '1.2 Max',
#   '1.2 Move',
#   '1.2 Cargo Plus',
#   '1.2 Move Plus',
#   '1.5l 4x2',
#   '1.2 Panel Carga',
#   '1.5 Max',
#   '1.2 Max Plus',
#   '1.2 Pasajeros',
#   '1.2 Cargo Max',
#   '1.2 Move Van',
#   '1.2 Van Move'],
#  'Soul': ['1.6 New Ex',
#   'New Soul 1.6',
#   '1.6',
#   '1.6 Ex',
#   '1.6 Lx',
#   'Six Pak',
#   '1.6lx Mt Full',
#   '1.6 Lx '],
#  'Super': ['Carry 1.0 Cargo',
#   'Carry 1.0 Furgon',
#   'Capry 1.0 Van',
#   'Carry Cargo Thermo'],
#  'Serie': ['3 M340i Xdrive',
#   '3 2.5 325i',
#   '3 2.0 320i',
#   '1 2.0 120i',
#   '5 2.0 530i',
#   '5 2.5 525i',
#   '4 2.0 M420i',
#   '3 2.0 318i',
#   '3 2.0 330e',
#   '3 2.0 F30',
#   '3 2.0 330',
#   '4 2.0 420i',
#   '2 2.0 G42',
#   '1 128 Ti',
#   '3 2.0 Paquete',
#   '7 4.0 740i',
#   '5 2.0 520i',
#   '5 2.0 G30',
#   '2 2.0 220i',
#   '2 3.0 M235i',
#   '3 2.0 Luxury',
#   '1 1.6 118i',
#   '1 1.6 116i',
#   '1 1.6 120i',
#   '3 3.0 335i',
#   '3 2.0',
#   '1 2.0',
#   '5 520i Premiun',
#   '4 1.5 Gran',
#   '7 3.0 740i',
#   '2 2.0 E87',
#   '2 3.0 M240i',
#   '3 330e Performance',
#   '2 220i F22',
#   '2 218i 1.5',
#   '2 1.5 218i',
#   '3 2.8 328i',
#   '3 320i 2.0',
#   '1 1.5 118i',
#   '3 2.0 G20',
#   '3 E90 Premium',
#   '3 1.6 316i',
#   '4 430i Gran',
#   '5 2.0 530e',
#   '3 2.5 E90',
#   '3 3.0 330i',
#   '3 318 I',
#   '1 Paquete M',
#   '1 F40 ',
#   '200 Cgi',
#   '4 2.0 F36',
#   '3 1.6 318i',
#   '3 330e 2.0',
#   '1 3.0 135i',
#   '2 218i Gran',
#   '2 218i F44',
#   '1 1.5 F40',
#   '1 E88 Cabriolet',
#   '3 325i 2.5',
#   '2 2.0 Gran',
#   '3 2.0 328i',
#   '1 120i 2.0t',
#   '3 2.0 330i',
#   '1 Bmw Serie',
#   '3 320i Sportline',
#   '4 2.0 ',
#   '1 116i Pack',
#   '3 Edición M',
#   '1 Xdrive',
#   '4 420i 2.0t',
#   '1 118i 1.6',
#   '1 E87 Sport',
#   '1 F20 Standard',
#   '2 220i ',
#   '3 I3 S',
#   '1 120i 2.0',
#   '3 1.5 318i',
#   '1 3.0 125i',
#   '1 120i 2.0l',
#   '1 2.0 128ti',
#   '3 320i Mt',
#   '1 F21 Mt'],
#  'Bronco': ['1.5 Sport Big',
#   '2.0 Wildtrak',
#   'Sport Big Bend',
#   'Sport 1.5 Big',
#   'Sport 1.5 Black',
#   'Sport 2.0 Wildtrak',
#   '5.0 Mt',
#   'Sport 2.0 Wildtrack',
#   'Big Bend',
#   'Sport',
#   'Sport Big'],
#  'Montero': ['2.5 4x4 At',
#   '2.5 Sport 178',
#   '3.0 V13',
#   'Hardtop',
#   'V11',
#   '3.5 V65',
#   '2.6 L042 Cabinado',
#   '3.0 V43 Wagon',
#   '3.5 Gls',
#   'Sport 4x4',
#   'Sport',
#   '3.5 Hard Blindaje',
#   '3.0 L146 Wagon',
#   '3.8 4x4',
#   '2.5 Diesel',
#   '3.5 V75 Wagon',
#   '3.5 Hard Top',
#   '2.4 V11',
#   '2.6 L042 Lona',
#   '3.2 V98 Wagon',
#   '3.0 V6 L146',
#   '3.0 L146 W',
#   '3.0 V43waa Pajero',
#   'Sport Takai At',
#   '2.4 V 11',
#   'V97 Wagon At',
#   '3.8 V97 Wagon',
#   'Montero Sport At',
#   '3.0',
#   'Sport 3.0',
#   '3.0 Takai 4x4',
#   'Hard Top'],
#  'Fusion': ['2.0 Titanium 245',
#   '2.0 Titanium Plus',
#   '2.0 Titanium',
#   '3.0',
#   '3.0 V6 Sel',
#   '3.0 Sel At',
#   '2.0 Sel Hev',
#   'Titanium Tp 2000cc',
#   '20. Turbo',
#   'Titanium'],
#  'Np300': ['Frontier 2.5 Cd',
#   'Frontier 25l',
#   'Frontier Le',
#   'Frontier 2.5l',
#   'Frontier 2.5 S',
#   'Frontier 2.5 Np300',
#   'Frontier 2.4l',
#   'Frontier 2.5 Le',
#   'Frontier 2.4 D22',
#   'Frontier 2.4l 4x2',
#   'Frontier 2.5 Furgon',
#   'Frontier 2.5 Frontier',
#   'Frontier 2.5 Mt',
#   'Frontier Mt 2.4',
#   'Frontier 2.5 ',
#   'Frontier 2.4 Furgon',
#   'Frontier 2.5l 4x2',
#   'Frontier 2.4l Mt'],
#  'Q3': ['1.4 Tfsi Ambition',
#   '1.4',
#   '1.4 S-line At',
#   '1.4 Tfsi Attraction',
#   '1.4 S-line Black',
#   '1.4  Tfsi',
#   '2.0 Tfsi Quattro',
#   '2.0 Sportback Quattro',
#   '1.4 Ambition',
#   '1.4 Sportback Tfsi',
#   'Sline',
#   '1.4  Sportback',
#   'Sportback 35 Tfsi',
#   '1.4 Sportback 35',
#   '2.0 T Fsi',
#   '2.0 T At',
#   '1.4 35 Tfsi',
#   'Tfsi Attraction',
#   '2.0',
#   '1.4 35tfsi De',
#   'Tfsi Ambition At'],
#  'Delta': ['Super Delta'],
#  'Land': ['Cruiser Prado Vx',
#   'Cruiser 300 3.4',
#   'Cruiser 4.2 Hdj100',
#   'Cruiser Grj71l',
#   'Cruiser 4.0 Fj73',
#   'Cruiser 4.5 Fzj73',
#   'Cruiser 4.5 Imperial',
#   'Cruiser 4.0 Vdj79',
#   'Cruiser 4.7 Uzj',
#   'Cruiser 4.0 Lx',
#   'Cruiser 1.6 Fj62',
#   'Cruiser 4.5 Executive',
#   'Cruiser 70 4.0',
# ...
#  'Uno': ['1.4 Way', 'Way', '1.0 Mille'],
#  'Joy': ['1.4 Mt Hatch',
#   '1.4 Sedan Mt',
#   '1.4 Lt',
#   '1.4 Ltz',
#   '1.4 Mt',
#   '1.4 Sedan',
#   'Hatchback Mt 1.4',
#   'Sedán 1.4',
#   '1.4 Lt Mt',
#   '1.4 Hatchback'],
#  'S60': ['1.6 T4 Premium', '1.6 T4 Kinetic', '2.0 T5', '3.0 T6 Awd', '1.6 T4'],
#  'Eq6390pf22qx': ['1.3'],
#  'Epica': ['2.5l', '2.5 Lt', '2.5l At', '2.5 At Triptonico', '2.0'],
#  '225xe': ['1.5', '1.5 Active Tourer'],
#  'Niro': ['1.6 Hibrido',
#   '1.6 Vibrant',
#   '1.6 Zenith Híbrido',
#   '1.6 Zenith Hibrido',
#   '1.6 Zenith Hybrido',
#   '1.6 Desire Híbrido',
#   '1.6 Zenith',
#   '1.6 Zenith Hibridó',
#   '1.6 Desire Hibrido'],
#  'John': ['Cooper Works 2.0', 'Cooper Works F56'],
#  'Kenbo': ['S3'],
#  'Clio': ['1.4 Fiv Dynamique',
#   '1.4 Cool',
#   'Campus',
#   'F.iv Rs Dynamique',
#   '1.4 Authentique Ii',
#   'F.iv Expression',
#   '1.2 Campus',
#   '1.6 Expression',
#   '1.4 F.ii Dynamique',
#   '1.2 Style Ca',
#   '1.2 Campus Mt',
#   'F.ii Dynamique',
#   '1.2 Style U',
#   '1.4 Authentique',
#   '1.2 Style',
#   '1.2 Sport Style',
#   '1.6 At Full',
#   '2.0 Sport',
#   '1.4 Rn',
#   '1.2 Campus Hard',
#   'F.iv Dynamique',
#   'Autentique',
#   '1.6 Campus',
#   '1.6',
#   '1.6 Ii Dynamique',
#   '1.4',
#   '1.4 Rte'],
#  '407': ['2.2 St'],
#  'Leon': ['1.6 Style Plus', '1.6 Style', '1.8 Fr Dsg', '1.6 Reference Mt'],
#  'Formentor': ['2.0 Tsi Mate', '2.0 Tsi Metalizado', '2.0', '2.0t'],
#  'Terios': ['1.5 J210lg', '1.5 Okii', '1.5 Okii 4x4'],
#  'Tacoma': ['Tr Pro 3.5', '3.5'],
#  'Beat': ['1.2 Ltz',
#   '1.2 Ls 80',
#   '1.2 Ls',
#   '1.2 Lt 80',
#   '1.2 Premier',
#   '1.2 Ltz Mecánica',
#   '1.2 Ls 81',
#   '1.2 Ltz Mt',
#   'Ls'],
#  'Getz': ['1.4 Gl',
#   '1.6 Gl',
#   'Hb20 Premium',
#   'Gl',
#   '1.6 Premium',
#   '1.6 Hb20',
#   '1.6 Advance Mt'],
#  'Ram': ['1500 1500 Big',
#   '2500 Laramie Blindaje',
#   '5.7 1500 Slt',
#   '1500 Hybrid 3.6',
#   '3.6 1500 Slt',
#   '3.6 1500 Hibrid',
#   '2500 2500 Heavy',
#   '5.7 4x4 Laramie',
#   '1500 Hybrida 3.6'],
#  'Vivant': ['2.0', '2.0 At'],
#  'Cherokee': ['3.7 Limited',
#   '3.2 Longitude Plus',
#   '4.0 Laredo Fl',
#   '4.0 Laredo',
#   'Longitude',
#   'Wagon',
#   '3.2 Longitude',
#   'Limited',
#   '3.2 Limited',
#   '3.7 Limited Liberty',
#   '3.7 Sport',
#   'Longtude',
#   '4.0 Xj'],
#  'Colorado': ['2.8 Ls',
#   '2.8 High Country',
#   'Ls',
#   '2.8 Lt',
#   '2.8 Ltz Mt',
#   '2.8 Z71'],
#  'L200': ['Sportero 3.2 At',
#   'Sportero 2.5 Superlujo',
#   'Sportero Sportero',
#   'Sportero 2.5 Pick-up',
#   '2.0 4x4',
#   '2.5 Full At',
#   'Sportero 2.5 High',
#   'Sportero 2.5',
#   'Sportero 2.5l High',
#   'Sportero 2.5 L',
#   '2.5l'],
#  'Korando': ['C 2.0 Active',
#   '2.0 C Fl',
#   '2.0 C Gasolina',
#   '2.0 C 4x2',
#   '2.0i C Gasgasol',
#   '1.5 Elite 4x2',
#   '2.0 C Diésel',
#   'G20d',
#   '2.0 C 4x4'],
#  'C': ['180 Avantrage Avantrage',
#   '180 Cgi Bluefficiency',
#   '200 Coupe',
#   '180 Gci Edicion',
#   '180 Avantgrade'],
#  'Van': ['1.2 Cargo Plus',
#   'N300 1.2',
#   'Carga 1.2',
#   'Carga 1.3 Eq5021xxxyf',
#   'Carga 1.25',
#   'Carga 1.2 12l',
#   'Cargo C35 1.5',
#   'Carga 1.3 Eq5021xxyf',
#   'Carga Eq5021xxyf',
#   'Carga 1.2 Eq5025xxyf13',
#   'Carga 1.0 Eq5021xxyf',
#   'Carga E Cargo',
#   'Pasajeros C37 1.4',
#   'Carga 1.3 C35',
#   'N200 1.2 Cargo',
#   'Pasajeros Lw 1.3'],
#  'Carens': ['2.0 Suv Ex', '2.0 Lx', '2.0 Suv', '2.0 Ex At', '2.0 Rondo Ex'],
#  'Virtus': ['1.6 Comfortline',
#   '1.6 Comfottline',
#   '1.6 Highline',
#   '1.6 Comfortline 4ab',
#   'Comfortline',
#   '1.6 Comfortline At',
#   'Highline'],
#  'Blazer': ['3.6 Rs 4x4',
#   '4.3 At 4x4',
#   '4.3 Ii Serie',
#   '3.6 Rs',
#   '3.6 Rs ',
#   '2.8 4x4',
#   '1.9',
#   '3.6 Blazer'],
#  'M240i': ['3.0 F22 Coupe'],
#  'Stonic': ['1.0 Zenith Hibrido',
#   '1.0  Zenith',
#   '1.0 Zenith',
#   '1.0 Vibrant Hybrid',
#   'Desire'],
#  'Fit': ['Ex I-vetec Automatico',
#   '1.5 Ex L',
#   '1.3 Lx',
#   '1.5 Ex',
#   '1.5 Lx',
#   '1.4 Lx'],
#  'A6': ['2.8 V6 Multitronic',
#   'Turbo 2.0',
#   'C6 24 Multitronic',
#   '55 Tfsi Quattro',
#   '2.8 Fsi Prestige',
#   '2.0 At'],
#  'Sirion': ['1.3l'],
#  'H100': ['2.4 Gran Saloon'],
#  'Idolphin': ['Electrico'],
#  'Rexton': ['270 Xdi', 'W 270xdi', '2.7 Rx 270', '2.9 Rx 290', 'Rx'],
#  'Fiorino': ['1.3 Fire', '1.2', '1.4 Fire 84', '1.4 Fire 87'],
#  '500': ['1.4 Lounge Convertible',
#   'Sport Bz',
#   '1.4 Sport Bz',
#   '1.4 Abarth',
#   '1.4 Sport At',
#   '1.4 Cabrio Automatico'],
#  'Q8': ['3.0 Tfsi Quattro'],
#  'Oroch': ['2.0 Dynamique', '1.3 Turbo Intens'],
#  'Crossland': ['1.2 Edition Tp'],
#  'Nhr': ['3.0 700p Reward', '2.8 700p Reward'],
#  'Focus': ['2.0 Titanium', 'Titanium', '2.0 Se', '2.0 Se At'],
#  'Baleno': ['1.4 Gl At', '1.4 Gl', 'Gl Mt', '1.4 Glx', '1.5'],
#  'Pathfinder': ['Exclusive',
#   '3.5 Exclusive',
#   '4.0 R51 Se',
#   '3.5 R52 Exclusive',
#   '3.5 R52 Advance',
#   '3.5 R50 Superlux',
#   'Le',
#   '3.5 R50 Ancha',
#   '2.5 Full Equipo',
#   '4 R52 Exclusive',
#   '3.5 Superlux',
#   '4.0 R51 Le',
#   '3.5 Sense',
#   '3.5 Exclusive At',
#   '3.5 R52 Sense',
#   '3.3 R50 Lux',
#   '3.5 Ancha'],
#  'Passat': ['2.0 Highline'],
#  'Q2': ['1.0 Tfsi Progressive', '1.0 Tfsi Ambition', 'Tfsi Ambition'],
#  'Odyssey': ['3.5 Exl',
#   '3.5 Exl Res',
#   '3.5 Exodo Res',
#   '3.5 5dr Ex-l',
#   '3.5 Exl At'],
#  'Ertiga': ['1.5 At 7', 'Mpv', '1.4 Mpv', '1.5 Gl Tp', '1.4'],
#  'Countryman': ['2.0 Cooper S', '1.6 Cooper S'],
#  'Trooper': ['3.2 960 4x4', '3.2 960', 'Dlx'],
#  'Wr-v': ['1.5 Ex', 'Lxc Mt', '1.5 Lx'],
#  '340i': ['3.0 M Edition'],
#  'Tahoe': ['Z71', '5.3 Lt'],
#  'Mb': ['140 Panel Van'],
#  'S2': ['1.5 Hfc7151eav', 'Hfc7151eav Mt 1500cc'],
#  'Tt': ['2.0 Tfsi S-tronic', '2.0 Tfsi Sport'],
#  '2008': ['1.6 Allure',
#   '1.6 Active',
#   '1.2 Gt Line',
#   '1.2 Allure Turbo',
#   '1.2 Allure',
#   '1.2 Allure At',
#   '1.2t Gt Line',
#   '1.6 Style',
#   '1.6'],
#  'R4': ['1.0 Gtl Master'],
#  'Berlingo': ['1.6 Cargo', '1.6'],
#  '308': ['1.6l', '1.6 Cc Cabriolet'],
#  'Zafira': ['2.0'],
#  'Veracruz': ['3.8 Gls', '3.8 Gl', '3.8'],
#  'B2600': ['2.6 Fi 4x4'],
#  'Impreza': ['2.0 Awd Sport', '2.0 Xv Limited', '1.5r Awd Gh'],
#  'Romeo': ['Giulietta 1.4 Distinctive',
#   'Mito 1.4 Distintive',
#   'Giulietta Distinctive',
#   'Mito 1.4 Distinctive',
#   'Mito Distintive'],
#  'Crossfox': ['1.6l',
#   '1.6 Wild',
#   '1.6',
#   '1.6 L',
#   '1.6 At',
#   '1.6 Wild At',
#   '1.6 Full Equipo',
#   '1.6 Mt',
#   '16l Mt 1600cc'],
#  'Alaskan': ['2.5 Cargo',
#   '2.5 Zen',
#   '2.5 Cargo Diesel',
#   '2.5 Mt',
#   '2.5 Cargo 4x4',
#   '2.5 Intens Dsl',
#   '2.5 Cargo Mt'],
#  'Cargo': ['1.2 Panel', '1.2 Bj5023xxy00-ab'],
#  'X70': ['1.5 Sport 4x2'],
#  'Civic': ['1.8 Ex L',
#   '1.6 Ex',
#   '1.5 Lx',
#   '1.6 Ex Vtec',
#   '1.8 Ex 4',
#   '1.6 Lx',
#   '1.8 Lx',
#   '1.8 Ex-sr At',
#   '1.8 Ex-l At',
#   '4dr Ex L5at',
#   '1.6',
#   '1.7 Lx',
#   '1.8 Ex-l'],
#  'I35': ['Elantra Gls'],
#  'E-tron': ['Advanced'],
#  '6': ['2.3 Secuencial Sunroof',
#   'Grand Touring Signature',
#   '2.5 Grand Touring',
#   'N3na6',
#   '2.0',
#   '2.5 Signature',
#   '2.0 Lxnm6',
#   '2.3 At L3na4',
#   'Lfna4',
#   '2.0 Lfnm4',
#   '2.5 L5na0'],
#  'Gx': ['4.6 460 Premium'],
#  'Yeti': ['1.8 City Elegance',
#   'Ambition 1.8',
#   '1.8 Experience',
#   '1.8 Ambition Mt'],
#  '626': ['2.0 Na8', '2.0 Nm0', '2.0 Na0', '2.0 Matsuri Nim', '2.0 Nao At'],
#  'Mobi': ['Easy', '1.0 Easy', '1.0 Like', '1.0 Easy Pop'],
#  'Lx': ['5.7 570 Super', '5.7 570'],
#  'Landwind': ['X5 Plus Jx6460lmm'],
#  'D2s': ['Electrico'],
#  'Glory': ['1.8 580 Mecánica', '580 1.8 Dxk', '580 1.8'],
#  'V40': ['1.6 T4 Kinetic',
#   'T4 Drive E-r',
#   '1.5 T3 Drive-e',
#   '1.6 T4 Energy',
#   '2.0 T4 R-desing'],
#  'Patrol': ['3.0 Y61 Sgl',
#   '4.0 Mt',
#   '4.8 Y61 Grx',
#   '4.0 Lg60',
#   'Grx',
#   '3.0 Y61 Grx',
#   '4.0 K160',
#   '4.2 Y60 Sgl',
#   '3.0 Y61 Gl'],
#  'Xc40': ['1.5 T5 Recharge',
#   '2.0 Kinetic',
#   '2.0 T4 Fwd',
#   '2.0 Hybrid 4x4',
#   'P8 Version Top',
#   '2.0 Hibrid',
#   '2.0',
#   '2.0 B5 Ultimate',
#   '2.0 T5 Awd',
#   'Recharge Ultimate 4x4',
#   'P8 Awd Recharge'],
#  'Hhr': ['2.4 Lt 2011'],
#  'Trailblazer': ['2.8 Ltz',
#   '3.6 Premier Ltz',
#   '4.2 Ltz 4x4',
#   '3.6 Premier At',
#   '2.8 Ltz Diesel'],
#  'Ibiza': ['1.6 Sport',
#   '1.4 Mt',
#   '1.6 Style At',
#   '1.4 Style',
#   '1.6 Style Dsg'],
#  'Evoltis': ['2.4t Limited', '2.4', 'Touring'],
#  'Coronet': ['2.5'],
#  'Ds7': ['1.6 Audace', 'Performance Line', '1.6 Crossback Audace'],
#  'Mustang': ['5.0 Gt Premium',
#   '5.0 Gt',
#   'Gt 5.0 Premium',
#   '3.7 V6 Convertible'],
#  'Scala': ['1.6l'],
#  'Carnival': ['2.9 Ex 2008', '2.9 Lx'],
#  'Seltos': ['1.6l Emotion At', '1.6l Vibrant At'],
#  'Cielo': ['Bx', '1.5 Bx 100'],
#  'A1': ['1.4 Tfsi Ambition',
#   '1.4 Ambition Plus',
#   '1.4 Sportback Tfsi',
#   'Ambition',
#   '1.4 Tfsi '],
#  '911': ['3.8 Carrera S', '3.8 Turbo S'],
#  'Durango': ['3.6 Sxt',
#   '3.6 Limited',
#   '3.6 Limited Plus',
#   'Sxt',
#   '3.6 Sxt 4x4',
#   '3.6 Gt'],
#  'Atos': ['1.0 Prime', '1.0 Santro'],
#  'Gt': ['1.5 Std'],
#  'F-pace': ['3.0 R-sport', '2.0 Prestige'],
#  'Yoya': ['1.3 Van Cargo', '1.5 Van Pass'],
#  'Hb20x': ['1.6 Advance Hb',
#   'Hb20x Graviti ',
#   '1.6 Gravity',
#   '1.6 Graviti Premium'],
#  'Wagon': ['R 1.2l'],
#  'Santamo': ['2.0'],
#  'Navara': ['2.5 High Lujo', '2.5 Ex Estacas'],
#  'Ix3': ['M Sport Inspiring',
#   'M Sport At',
#   'Inspiring M Tp',
#   'Ix3 M 4x2',
#   'M Sport'],
#  'Asx': ['2.',
#   '2.0 Triptonico',
#   '2.0 4x4 Full',
#   '2.0 Gls Mt',
#   '2.0 Gls',
#   '2.0 200 4x4',
#   '2.0 Glx',
#   '2.0 L At'],
#  'E-pace': ['2.0 E Pace', '2.0 I4 S', '2.0 E-pace', '2.0 Se Tp', '2.0  Se'],
#  'C5': ['1.6 T Aircross', '1.6 Aircross', '2.0 Sx Fase', 'Aircross Unique'],
#  '2181i': ['1.5'],
#  'Kona': ['1.6 Hibrida At',
#   '1.6 Premium Híbrida',
#   '1.6 Limited Hibrido',
#   'Premium Hibrida',
#   '1.6 Híbrida Premium',
#   '1.6 Hibrida',
#   '1.6 Hybrida'],
#  'Amg': ['3.0 4matic 2022',
#   'Glc 43 4matic',
#   '2.0 A45 Amg',
#   '2.0 A45 4matic',
#   '3.0 C 43'],
#  'I20': ['1.4', '1.4 Premium', '1.4 Active'],
#  'Nubira': ['1998'],
#  'Camaro': ['6.2 Ss'],
#  'C30': ['2.4 Full Equipo', '2.0', '2.5 T5 Premium', '2.0 R-design', '2.0 Mt'],
#  'Estacas': ['4.5 4.5'],
#  'Hb20s': ['1.6 Advance At', '1.6 Advance'],
#  'Gladiator': ['3.6 Rubicon'],
#  '350': ['2.0', '1.5 Comfort'],
#  '250': ['2.0'],
#  'X2': ['2.0 M35i Xdrive', '2.0 Sdrive 20i', '2.0 X2 Sdrive20i'],
#  'Sonata': ['2.4 Gls'],
#  '325i': ['2.5'],
#  'Yuan': ['Plus Ev', 'Plus Ev 480', 'Ev-400 Gls'],
#  'Bmw': ['523 I 2.5'],
#  'B': ['200 1.6'],
#  'Rapid': ['1.6 Style Montecarlo'],
#  'Cheyenne': ['5.3 K1500 Stepside', '5.0 Silverado'],
#  'Ioniq': ['1.6 Hev Hibrido', '1.6 Attraction', '1.6 Limited'],
#  '116': ['I 1.6 Sportline'],
#  'Xl7': ['Glx'],
#  'Tiggo': ['1500 Mt', '2 1.5 Luxury', '1.6 Fl', '1.6l', '2 1.5 Comford'],
#  '190': ['E 190 E'],
#  'M3': ['4.0 M3 E92', '2.0'],
#  'H3': ['3.7 Luxury At', '3.7l Lux'],
#  'Corsa': ['Wind',
#   '1.4 Wind',
#   '1.4 Active',
#   '1.4 L Evolution',
#   '1.4l Evolution 5p',
#   'Active'],
#  'K3': ['1.6 Gt Line'],
#  'D21': ['2.0', '2.4 4x2', '2.0l'],
#  'Z4': ['2.0 Sdrive20i', 'Sdrive 20 I'],
#  'Rx': ['350h Luxury'],
#  'Zoe': ['Life Electrico', 'Zen', '68kw  Life'],
#  'Pulse': ['1.3 Drive Mt', 'Drive'],
#  'Gle': ['250 Cdi 4matic', '450 4matic Hibrido'],
#  'Partner': ['1.6l', '1.6 Diesel', '1.6 Cargo'],
#  'I30': ['2.0 At', '1.6 Gls'],
#  'D22/np300': ['2.4 Np 300'],
#  '5008': ['1.6 Allure',
#   '2.0 Gt Line',
#   '1.6 Gt-line',
#   '1.6 Gt Line',
#   '1.6 Gt-line Aut',
#   'Allure'],
#  'M': ['240i Coupe'],
#  'Orlando': ['2.4 Lt'],
#  'V5': ['1.5 Deluxe', '1.5 Sport', '1.5 Sport Turbo', 'Turbo 1.5'],
#  'Fabia': ['1.2 Combi Fl',
#   '1.6 Hb Ambiente',
#   '1.2 Hb Twincam',
#   '1.2 Clasic Mt'],
#  'K': ['2.5 2500 Ii', '2500'],
#  'Glc250': ['4matic'],
#  '306': ['1.8 Sr', '1.4 Xn 4'],
#  'Yoki': ['1.1 Furgon', '1.0 4x2'],
#  '635': ['Csi 3.5 '],
#  'Mx-30': ['Grand Touring At', '105 Kw Fwd'],
#  'N400': ['1.5 Max Cargo', '1.5 Mini Van', '1.5 Cargo'],
#  'Marvel': ['R+ Electrico'],
#  'M2': ['Cabrio', '3.0 F87 Coupe'],
#  'Transporter': ['2.0 Kombi T5', '2.0 T5 Diesel'],
#  'Nivus': ['1.0 Comfortline',
#   '1.0 Highline At',
#   '1.0 Highline',
#   '1.0 At Comfortline',
#   '1.0t Highline At'],
#  'Qin': ['Plus Dmi'],
#  'Sj': ['1.3 410 Qlc', '1.3 413', '410 Campero 1.3'],
#  'Ateca': ['1.4 Style Sport',
#   'Style Sport',
#   '1.4t Style Sport',
#   '2.0 Style',
#   '2.0 Style Sport'],
#  'Festiva': ['1.3 Casual Mt'],
#  'Safrane': ['3.0 Rn'],
#  'Master': ['2.3l Mt ', '2.5 Confort', '2.3', '2.3l'],
#  'Xinyi': ['1.0 Hfj6376 Cargo'],
#  'X6': ['3.0 Xdrive40i',
#   '3.0 Xdrive35i',
#   '3.0 Xdrive40i Paquete',
#   '3.0 Xdrive35i At'],
#  'Cx-7': ['2.3 Cx7l30', '2.3 Cx7l3t', '2.5 At'],
#  'Burbuja': ['4.5 Autana Fzj80', '4.5 Land Cruiser', '4.5 Vx'],
#  '5': ['2.0 At Full', '2.0 Lxwm8'],
#  'Tribeca': ['3.6l Awd'],
#  'Raptor': ['F-150 Svt 6.2'],
#  'Damas': ['0.8 Dlx'],
#  'Optima': ['Hibrido'],
#  'Leaf': ['Leaf'],
#  'F-350': ['5.8'],
#  'C200': ['1.8 Classic'],
#  'Almera': ['1.6 Slx 4', '1.6 Sg', '1.6 Sg Mt'],
#  '1300/113': ['Escarabajo'],
#  'S-presso': ['1.0', '1.0 Ga'],
#  'Xl-7': ['1.5 Mt 7'],
#  'Cronos': ['1.3 Drive'],
#  'Mx-5': ['Grand Touring Lx', 'Sport'],
#  'Morris': ['1.3'],
#  'Chevy': ['1.6 C2 5', '1.6 C2 4'],
#  'L300': ['2.0 Panel'],
#  'Xsara': ['Picasso 2.0 Exclussive', '1.8 Sx'],
#  'S3': ['2.0 Quattro Sport', '1.6 Hfc7161mv'],
#  'I10': ['1.1 Gl', 'Gl Mt', '1.2 Gl Mt'],
#  'Highlander': ['3.5'],
#  'Eq1020tf': ['1.3 Furgón Refrigerado', '1.1 Asl'],
#  'Palio': ['Weekend 1.6 Elx',
#   '1.6 Adventure',
#   '1.3 Ex Fire',
#   '1.3 Fire',
#   '1.3 Edx',
#   'Weekend 1.4 Attractive',
#   '1.4 Elx Attractive',
#   'Elx'],
#  'Mini': ['Van 1.2 Carga',
#   'Van 1.4 Start',
#   'Van 1.2 Van',
#   'Truck 1.2 Bj1030v4jv2-bh'],
#  '320i': ['2.0 F30 Sportline'],
#  'Kuv100': ['1.2 Nxt 2ab'],
#  'Gla': ['200 Amg Line', '200 Urban'],
#  'Urvan': ['3.0 Diesel', '3.0 Diesel Techo', 'Nv 350 Full', '3.0 Panel'],
#  '208': ['1.6 Active Vti', '1.6 Allure', '1.6 Active Hdi'],
#  'Porter': ['2.6 H100'],
#  'Sendero': ['1.6 Authentique'],
#  'Torres': ['1.5 Elite 4x2'],
#  'Rush': ['1.5 High 7', '1.5 High', '1.5 At'],
#  'Wrx': ['Fa 2.0l Mt'],
#  'Expert': ['2.0 Turbo Diésel'],
#  'Sonet': ['1.5 Vibrant', '1.5 Vibrant At', '1.5l Vibrant', '1.6 Vibrant At'],
#  'Tonic': ['1.6 Vibrant'],
#  '4.6': ['4.6'],
#  'K05': ['1.2'],
#  '2004': ['3.2'],
#  'Cobalt': ['1.8 Lt'],
#  'Neon': ['Lx 2.0'],
#  '230': ['E', '1.5'],
#  'Crx': ['1.6 Del Sol'],
#  'M5': ['Competicion'],
#  'Tivoli': ['16 Elite At4x2', '1.5 Xlv '],
#  'Mégane': ['Iii 2.0 Full'],
#  'Jcw': ['2.0 F56 John'],
#  'Felicia': ['1.3 Lxi Fl'],
#  'Caddy': ['1.6 Panel Furgón'],
#  'J3': ['1.3 Turin'],
#  'Gala': ['2.0 Mt Superior'],
#  'Pik-up': ['2.2 116 Hp', '2.2 Mid'],
#  'Yo-yo': ['Mini Van'],
#  '218i': ['Active Tourer'],
#  '180': ['1.6'],
#  'Scénic': ['Dynamique', 'Ii 2.0 At', '1.6 Mt'],
#  'Octavia': ['1.6 Ambiente', '1.8 Tfsi Ambiente', '1.8 Elegance Combi'],
#  'Tunland': ['2.8 Diesel 4x4',
#   '2.8 Bj2037y3mdv Mt',
#   'Bj2037y3mdv Mt 2.8',
#   '2.8 Diesel Mt'],
#  'X': ['Trail T30 2.5'],
#  '307': ['2.0 Xt Feline'],
#  '2105': ['1.6 2105-3'],
#  '323': ['1.3 Ns 4', '1.5 Nb', '1.3 He'],
#  'Sequoia': ['3.5 Capstone', '5.7 4x4 Blindado'],
#  'Sprint': ['1.0', '1.0 Mt'],
#  '330i': ['G20 Sportline At'],
#  'Grandland': ['X 1.6 T'],
#  'Boxster': ['3.4 S Roadster'],
#  'Expedition': ['3.5 Bt ', '3.5 Limited'],
#  'C40': ['Recharge Ultimate Pure'],
#  'Cayenne': ['3.6 V6', '3.6 V6 Lux'],
#  'Racer': ['1.5 Gti Mt'],
#  'Eon': ['0.8 Active', '0.8 Style'],
#  'Cs15': ['1.5 Luxury Mt'],
#  'Veloster': ['1.6 Coupe'],
#  'Juke': ['1.6l 4x4 Turbo', 'Hatchback'],
#  'F150': ['3.5 Xlt', '5.4 Xlt Tritron'],
#  'Primera': ['2.0 Gxe'],
#  'Nuevo': ['Jetta Comfortline', 'Jetta Trendline'],
#  'A': ['200 1.3', '200 Progressive'],
#  '320': ['I 2.0 E30', '2.0 F30 Executive'],
#  'Cadenza': ['3.5 Ex'],
#  'Gl': ['500 4.7 4matic'],
#  'Demio': ['1.3 Dem3m4'],
#  'Quin': ['Plus 1.5 Dm-i', 'Plus Dm-i At'],
#  'C250': ['Amg Line'],
#  'Yoyo': ['1.2l Comfort'],
#  'Sedona': ['2.9 Ex'],
#  '1000': ['1.8 Big Horn'],
#  'Superb': ['1.9 Tdi Elegance', '2.8 Comfort'],
#  '301': ['1.6 Allure'],
#  'Ad': ['Wagon 1.6 Std'],
#  'Glk300': ['4matic Plus'],
#  'Eclipse': ['Cross Croos'],
#  'Cx-90': ['3.3t Hybrid 7'],
#  'B-cross': ['1.5 Hfc7150m'],
#  'Hb20': ['1.4 Premium'],
#  'Soluto': ['1.4 Emotion Aut', '1.4 Emotion'],
#  'Ciaz': ['1.4 Sedan'],
#  '500c': ['Lounge Cabriolet At'],
#  'Mohave': ['3.0'],
#  'Opirus': ['3.8 Gsl'],
#  'Amigo': ['2.6'],
#  '406': ['2.0 St'],
#  'Nueva': ['Ranger 2.6 Xlt'],
#  'Clk': ['5.0 Cabriolet'],
#  'Spacefox': ['1.6 Mt'],
#  'Countryman\xa0hibrid': ['1.5 Hybrid'],
#  'Qq3': ['0.8'],
#  'Apv': ['1.6l'],
#  'S4': ['4.2 V8 Quattro'],
#  'Rodius': ['2.0 D20dtr'],
#  'Esteem': ['1.3  Mt'],
#  'Dolphin': ['Electrico'],
#  '1500': ['Slt 3.6'],
#  'B2000': ['2.0 B2000'],
#  'Glx': ['All Grip At'],
#  'H1': ['2.5 Pasajeros Publica']}

# %%
data[data['vehicle_line']=='Cerato']
# Out:
#       Unnamed: 0                           product     price  \
# 91            91               Kia Cerato Forte Sx  36800000
# 185          185                  Kia Cerato Vivro  66000000
# 243          243           Kia Cerato Forte 2.0 Sx  42000000
# 266          266               Kia Cerato Pro 1.6l  46900000
# 284          284                 Kia Cerato 1.6 Sx  45000000
# ...          ...                               ...       ...
# 8818        8818          Kia Cerato Koup 2.0 Koup  35000000
# 8889        8889      Kia Cerato 1.6 Vivro Vibrant  62500000
# 9438        9438        Kia Cerato Pro 1.6l 130 Hp  56000000
# 9454        9454  Kia Cerato 1.6 Vivro Vibrant Aut  63600000
# 9497        9497           Kia Cerato Forte 1.6 Sx  40000000
#
#                                                    link  years  kilometraje  \
# 91    https://carro.mercadolibre.com.co/MCO-24604410...   2011       118500
# 185   https://carro.mercadolibre.com.co/MCO-22176547...   2019        57000
# 243   https://carro.mercadolibre.com.co/MCO-13930919...   2013        66000
# 266   https://carro.mercadolibre.com.co/MCO-22128561...   2014       139563
# 284   https://carro.mercadolibre.com.co/MCO-13927429...   2013        84637
# ...                                                 ...    ...          ...
# 8818  https://carro.mercadolibre.com.co/MCO-24426614...   2012        90900
# 8889  https://carro.mercadolibre.com.co/MCO-24291487...   2019        40500
# 9438  https://carro.mercadolibre.com.co/MCO-14720113...   2017        95496
# 9454  https://carro.mercadolibre.com.co/MCO-24391998...   2020        50100
# 9497  https://carro.mercadolibre.com.co/MCO-14353369...   2012        75000
#
#                  _created vehicle_make vehicle_line          id  \
# 91             2024-06-20          Kia       Cerato  2460441032
# 185   2024-02-24 13:24:53          Kia       Cerato  2217654792
# 243   2024-02-24 13:24:53          Kia       Cerato  1393091943
# 266   2024-02-24 13:24:53          Kia       Cerato  2212856152
# 284   2024-02-24 13:24:53          Kia       Cerato  1392742945
# ...                   ...          ...          ...         ...
# 8818           2024-06-12          Kia       Cerato  2442661422
# 8889           2024-06-06          Kia       Cerato  2429148762
# 9438           2024-08-28          Kia       Cerato  1472011369
# 9454           2024-06-11          Kia       Cerato  2439199820
# 9497           2024-06-11          Kia       Cerato  1435336985
#
#        location_city location_state            version
# 91          Fontibón    Bogotá D.C.           Forte Sx
# 185   Ciudad Bolívar    Bogotá D.C.              Vivro
# 243   Barrios Unidos    Bogotá D.C.       Forte 2.0 Sx
# 266   Ciudad Bolívar    Bogotá D.C.           Pro 1.6l
# 284         Medellín      Antioquia             1.6 Sx
# ...              ...            ...                ...
# 8818            Bosa    Bogotá D.C.      Koup 2.0 Koup
# 8889         Kennedy    Bogotá D.C.  1.6 Vivro Vibrant
# 9438         Usaquén    Bogotá D.C.       Pro 1.6l 130
# 9454            Suba    Bogotá D.C.  1.6 Vivro Vibrant
# 9497            Bosa    Bogotá D.C.       Forte 1.6 Sx
#
# [70 rows x 13 columns]
